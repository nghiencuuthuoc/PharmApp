# %% [markdown]
# <a href="https://github.com/nghiencuuthuoc/PharmApp/PharmApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# ![](./images/PharmApp-logo.png)
# # PharmApp - Drug Discovery and Development
# Copyright 2024 | Nghiên Cứu Thuốc | RD_Pharma_Plus
#
# Email: nghiencuuthuoc@gmail.com | http://www.nghiencuuthuoc.com | https://twitter.com/nghiencuuthuoc | https://facebook.com/nghiencuuthuoc

# %% [markdown]
# # View table sagerx

# %%
from IPython.display import display, HTML
display(HTML("<style>:root { --jp-notebook-max-width: 100% !important; }</style>"))
# Out:
# <style>:root { --jp-notebook-max-width: 100% !important; }</style>

# %%
import sys
sys.path.append('..')
import os
os.getcwd()
# Out:
# 'D:\\PharmApp\\notebook'

# %%
import pandas as pd

# %%
 SAGERX_FOLDER = '../sagerxdata'

# %% [markdown]
# <!-- import pandas as pd
#
# SAGERX_FOLDER = 'sagerxdata'
#
# dose_form_name = pd.read_csv(SAGERX_FOLDER + "/dose_form_name.csv"); dose_form_name.head()
# products_to_inactive_ingredients = pd.read_csv(SAGERX_FOLDER + "/products_to_inactive_ingredients.csv"); products_to_inactive_ingredients.head()
# dailymed_interaction = pd.read_csv(SAGERX_FOLDER + "/sagerx.dailymed_interaction.csv"); dailymed_interaction.head()
# dailymed_main = pd.read_csv(SAGERX_FOLDER + "/sagerx.dailymed_main.csv"); dailymed_main.head()
# dailymed_organization_text = pd.read_csv(SAGERX_FOLDER + "/sagerx.dailymed_organization_text.csv"); dailymed_organization_text.head()
# dailymed_daily = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.dailymed_daily.csv"); dailymed_daily.head()
# dailymed_pharm_class = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.dailymed_pharm_class.csv"); dailymed_pharm_class.head()
# dailymed_rxnorm = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.dailymed_rxnorm.csv"); dailymed_rxnorm.head()
# dailymed_zip_file_metadata = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.dailymed_zip_file_metadata.csv"); dailymed_zip_file_metadata.head()
# fda_enforcement = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_enforcement.csv"); fda_enforcement.head()
# fda_excluded_package = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_excluded_package.csv"); fda_excluded_package.head()
# fda_excluded_product = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_excluded_product.csv"); fda_excluded_product.head()
# fda_excluded_product.proprietaryname = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_excluded_product.proprietaryname.csv"); fda_excluded_product.proprietaryname.head()
# fda_ndc_package = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_ndc_package.csv"); fda_ndc_package.head()
# fda_ndc_product = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_ndc_product.csv"); fda_ndc_product.head()
# fda_ndc_product.proprietaryname = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_ndc_product.proprietaryname.csv"); fda_ndc_product.proprietaryname.head()
# fda_unfinished_product = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_unfinished_product.csv"); fda_unfinished_product.head()
# fda_unii = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_unii.csv"); fda_unii.head()
# nadac = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.nadac.csv"); nadac.head()
#  -->

# %%
products_to_inactive_ingredients = pd.read_csv(SAGERX_FOLDER + "/products_to_inactive_ingredients.csv", low_memory=False)
products_to_inactive_ingredients.head()
# Out:
#         ndc9        ndc  product_rxcui  \
# 0  000020152  0002-0152        2679323
# 1  000020152  0002-0152        2679323
# 2  000020152  0002-0152        2679323
# 3  000020152  0002-0152        2679323
# 4  000020152  0002-0152        2679323
#
#                                         product_name product_tty  \
# 0  tirzepatide 2.5 mg in 0.5 mL SUBCUTANEOUS INJE...          DP
# 1  tirzepatide 2.5 mg in 0.5 mL SUBCUTANEOUS INJE...          DP
# 2  tirzepatide 2.5 mg in 0.5 mL SUBCUTANEOUS INJE...          DP
# 3  tirzepatide 2.5 mg in 0.5 mL SUBCUTANEOUS INJE...          DP
# 4  tirzepatide 2.5 mg in 0.5 mL SUBCUTANEOUS INJE...          DP
#
#   inactive_ingredient_unii  inactive_ingredient_rxcui  \
# 0               059QF0KO0R                      11295
# 1               451W47IQ8X                       9863
# 2               55X04QC32I                       9880
# 3               70WT22SF4B                     221090
# 4               QTT17582CB                       5486
#
# ...

# %%
rxterms = pd.read_csv(SAGERX_FOLDER + "/rxterms.csv")
rxterms.head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 rxterms = pd.read_csv(SAGERX_FOLDER + "/rxterms.csv")
#       2 rxterms.head()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
rxterms_full_name = rxterms[['full_name']]
rxterms_full_name.head()
# Out:
#                                            full_name
# 0  amlodipine 5 MG / hydrochlorothiazide 12.5 MG ...
# 1  amlodipine 5 MG / hydrochlorothiazide 25 MG / ...
# 2  amlodipine 5 MG / hydrochlorothiazide 25 MG / ...
# 3  dimethicone 100 MG/ML / miconazole nitrate 20 ...
# 4                         doxepin 10 MG Oral Capsule

# %%
file_excel_name = 'rxterms_full_name.xlsx'
name_sheet = 'rxterms_full_name'
path_formula_export = '../sagerxdata'
path_file_excel_formula = path_formula_export +'/' + file_excel_name
with pd.ExcelWriter(path_file_excel_formula) as writer:
    rxterms_full_name.to_excel(writer, sheet_name = name_sheet)

# %%
dose_form_name = pd.read_csv(SAGERX_FOLDER + "/dose_form_name.csv"); dose_form_name.head()
# Out:
#         dose_form_name
# 0          Oral Tablet
# 1        Topical Spray
# 2  Injectable Solution
# 3  Injectable Solution
# 4      Oral Suspension

# %%
# products_to_inactive_ingredients = pd.read_csv(SAGERX_FOLDER + "/products_to_inactive_ingredients.csv"); products_to_inactive_ingredients.head()

# %%
dailymed_interaction = pd.read_csv(SAGERX_FOLDER + "/sagerx.dailymed_interaction.csv"); dailymed_interaction.head()
# Out:
#                                              spl  \
# 0  20240810_4d812277-21a8-4de3-b728-e3fdd01305b5
# 1  20240810_f3dc2a50-1084-4190-a6f3-37034a04db86
# 2  20240810_eeda90a0-4941-4716-8684-f9f12cbdf3af
# 3  20240810_83bf40fa-6ae1-4811-8dc1-e8c0bcd63d78
# 4  20240812_ca749349-d0e1-4b7c-b4c0-e392e72cf0f6
#
#                             document_id                                set_id  \
# 0  2a692e09-a7a7-42e4-bbec-fb550493aa0b  4d812277-21a8-4de3-b728-e3fdd01305b5
# 1  5a7e5bff-625b-43d0-9a1f-16cb83f4ad04  f3dc2a50-1084-4190-a6f3-37034a04db86
# 2  edc0d10b-1a9d-4038-9fe0-029523646314  eeda90a0-4941-4716-8684-f9f12cbdf3af
# 3  ba6c818a-9f0c-4a5d-a493-3f7c9c805c26  83bf40fa-6ae1-4811-8dc1-e8c0bcd63d78
# 4  aa80d055-5a91-4d33-98b7-101ac2fa9b1e  ca749349-d0e1-4b7c-b4c0-e392e72cf0f6
#
#    version_number                                   interaction_text
# 0               5  \n               \n               \n          ...
# ...

# %%
dailymed_main = pd.read_csv(SAGERX_FOLDER + "/sagerx.dailymed_main.csv"); dailymed_main.head()
# Out:
#                                              spl  \
# 0  20240810_4d812277-21a8-4de3-b728-e3fdd01305b5
# 1  20240810_f3dc2a50-1084-4190-a6f3-37034a04db86
# 2  20240810_eeda90a0-4941-4716-8684-f9f12cbdf3af
# 3  20240810_83bf40fa-6ae1-4811-8dc1-e8c0bcd63d78
# 4  20240812_ca749349-d0e1-4b7c-b4c0-e392e72cf0f6
#
#                             document_id                                set_id  \
# 0  2a692e09-a7a7-42e4-bbec-fb550493aa0b  4d812277-21a8-4de3-b728-e3fdd01305b5
# 1  5a7e5bff-625b-43d0-9a1f-16cb83f4ad04  f3dc2a50-1084-4190-a6f3-37034a04db86
# 2  edc0d10b-1a9d-4038-9fe0-029523646314  eeda90a0-4941-4716-8684-f9f12cbdf3af
# 3  ba6c818a-9f0c-4a5d-a493-3f7c9c805c26  83bf40fa-6ae1-4811-8dc1-e8c0bcd63d78
# 4  aa80d055-5a91-4d33-98b7-101ac2fa9b1e  ca749349-d0e1-4b7c-b4c0-e392e72cf0f6
#
#    version_number  effective_date           market_status application_number  \
# 0               5        20240809  NDA authorized generic          NDA216743
# ...

# %%
dailymed_organization_text = pd.read_csv(SAGERX_FOLDER + "/sagerx.dailymed_organization_text.csv"); dailymed_organization_text.head()
# Out:
#                                              spl  \
# 0  20240810_0a4ca401-6ea4-4653-8674-056fa637f4a1
# 1  20240810_174ef537-e3e6-42bd-a478-47b930ddc761
# 2  20240810_1a33dec1-8d59-48bd-aaef-77d162194d57
# 3  20240810_1b2c973f-82ef-a4f3-e063-6394a90aaae0
# 4  20240810_1ef5693b-d00a-28fb-e063-6294a90a7ede
#
#                             document_id                                set_id  \
# 0  1235e7ee-d6db-440e-a680-999dc3295d2e  0a4ca401-6ea4-4653-8674-056fa637f4a1
# 1  d65887ab-ec81-4f50-81b6-3cda2262e2e5  174ef537-e3e6-42bd-a478-47b930ddc761
# 2  7c702061-6604-4b46-b035-dd0fb4d25165  1a33dec1-8d59-48bd-aaef-77d162194d57
# 3  1f42392a-ef99-86c1-e063-6294a90ae0af  1b2c973f-82ef-a4f3-e063-6394a90aaae0
# 4  1f42ded9-a828-39d8-e063-6294a90a953c  1ef5693b-d00a-28fb-e063-6294a90a7ede
#
#                                    organization_text  row_num
# 0  \n                  \n                      \n...        1
# 1  \n                  \n                     Pat...        1
# ...

# %%
dailymed_daily = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.dailymed_daily.csv"); dailymed_daily.head()
# Out:
#                                              spl  \
# 0  20240810_4d812277-21a8-4de3-b728-e3fdd01305b5
# 1  20240810_f3dc2a50-1084-4190-a6f3-37034a04db86
# 2  20240810_eeda90a0-4941-4716-8684-f9f12cbdf3af
# 3  20240810_83bf40fa-6ae1-4811-8dc1-e8c0bcd63d78
# 4  20240812_ca749349-d0e1-4b7c-b4c0-e392e72cf0f6
#
#                                   file_name  \
# 0  2a692e09-a7a7-42e4-bbec-fb550493aa0b.xml
# 1  5a7e5bff-625b-43d0-9a1f-16cb83f4ad04.xml
# 2  edc0d10b-1a9d-4038-9fe0-029523646314.xml
# 3  ba6c818a-9f0c-4a5d-a493-3f7c9c805c26.xml
# 4  aa80d055-5a91-4d33-98b7-101ac2fa9b1e.xml
#
#                                          xml_content
# 0  <dailymed>\n  <documentId>2a692e09-a7a7-42e4-b...
# 1  <dailymed>\n  <documentId>5a7e5bff-625b-43d0-9...
# 2  <dailymed>\n  <documentId>edc0d10b-1a9d-4038-9...
# 3  <dailymed>\n  <documentId>ba6c818a-9f0c-4a5d-a...
# 4  <dailymed>\n  <documentId>aa80d055-5a91-4d33-9...

# %%
dailymed_pharm_class = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.dailymed_pharm_class.csv"); dailymed_pharm_class.head()
# Out:
#                               spl_setid  spl_version  \
# 0  000155a8-709c-44e5-a75f-cd890f3a7caf           27
# 1  0002ad27-779d-42ab-83b5-bc65453412a1           25
# 2  0002eded-a283-4590-a78c-b6ff2027e684            1
# 3  0003458f-352a-46fa-9d99-230daa76ae29           10
# 4  0003eccd-6147-4a7c-ae83-b2a94933e07d            7
#
#                            pharma_setid  pharma_version
# 0  c29a4f1b-49e6-46a6-aefe-820474b74d5f               2
# 1  02f4926a-415c-4085-b6be-417f20cc1d71               2
# 2  ff3fd145-6f50-4a4d-ac9d-5f277860bf91               4
# 3  03e2633d-120e-47dc-95a0-03c4d9c1e077               2
# 4  ec138ad1-672f-4eaf-8b27-aa99ef213fa2               2

# %%
dailymed_rxnorm = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.dailymed_rxnorm.csv"); dailymed_rxnorm.head()
# Out:
#                                   setid  spl_version    rxcui  \
# 0  000155a8-709c-44e5-a75f-cd890f3a7caf           27   198014
# 1  000155a8-709c-44e5-a75f-cd890f3a7caf           27   198014
# 2  0001d1cf-f727-4875-a44f-5a51f7b617a4            2  1046593
# 3  0001d1cf-f727-4875-a44f-5a51f7b617a4            2  1046593
# 4  0001d1cf-f727-4875-a44f-5a51f7b617a4            2  1046593
#
#                                                rxstr rxtty
# 0                        naproxen 500 MG Oral Tablet   PSN
# 1                        naproxen 500 MG Oral Tablet   SCD
# 2  benzalkonium chloride 0.13 % Medicated Liquid ...   PSN
# 3  benzalkonium chloride 0.13 % Medicated Liquid ...    SY
# 4  benzalkonium chloride 1.3 MG/ML Medicated Liqu...   SCD

# %%
dailymed_zip_file_metadata = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.dailymed_zip_file_metadata.csv"); dailymed_zip_file_metadata.head()
# Out:
#                                   setid  \
# 0  a661a6c8-0eb3-0b28-e053-2a95a90a66fe
# 1  94d13f48-fbca-67b4-e053-2995a90a791b
# 2  25500fd1-4fee-43db-9c71-45912594fe06
# 3  7508ce57-40bc-4d50-8025-44d28bfc2ccb
# 4  a338f711-734c-07d3-e053-2a95a90aed79
#
#                                        zip_file_name upload_date  spl_version  \
# 0  20200524_a661a6c8-0eb3-0b28-e053-2a95a90a66fe.zip  05/26/2020            1
# 1  20240131_94d13f48-fbca-67b4-e053-2995a90a791b.zip  01/31/2024            4
# 2  20091231_25500fd1-4fee-43db-9c71-45912594fe06.zip  10/09/2010            1
# 3  20091231_7508ce57-40bc-4d50-8025-44d28bfc2ccb.zip  10/09/2010            1
# 4  20200419_a338f711-734c-07d3-e053-2a95a90aed79.zip  04/20/2020            3
#
#                                                title
# 0  (BIOTEMED) INSTANT HAND SANITIZER (ALCOHOL) GE...
# 1  (CHLOROPROCAINE HCI INJECTION, SOLUTION [HF AC...
# 2  (DEODORANT PLUS ANTIPERSPIRANT) STICK [RAANI C...
# ...

# %%
fda_enforcement = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_enforcement.csv"); fda_enforcement.head()
# Out:
#    index      status          city state        country classification  \
# 0      0  Terminated   Lake Forest    IL  United States       Class II
# 1      1     Ongoing  East Windsor    NJ  United States       Class II
# 2      2  Terminated   Lake Zurich    IL  United States       Class II
# 3      3  Terminated   Lake Forest    IL  United States        Class I
# 4     11  Terminated     Hauppauge    NY  United States       Class II
#
#                                              openfda product_type  event_id  \
# 0  {"application_number": ["ANDA070583"], "brand_...        Drugs     69247
# 1  {"application_number": ["ANDA210965"], "brand_...        Drugs     95059
# 2  {"application_number": ["ANDA075154"], "brand_...        Drugs     63451
# 3  {"application_number": ["ANDA070583"], "brand_...        Drugs     66260
# 4                                                 {}        Drugs     78822
#
#             recalling_firm  ... recall_number  \
# ...

# %%
fda_excluded_package = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_excluded_package.csv"); fda_excluded_package.head()
# Out:
#                                         productid productndc ndcpackagecode  \
# 0  0002-0604_043d7847-900a-48f5-8f08-a88d14645706  0002-0604   0002-0604-40
# 1  0002-1210_e82b7e9c-6569-415d-9498-084612225c12  0002-1210   0002-1210-30
# 2  0002-1210_e82b7e9c-6569-415d-9498-084612225c12  0002-1210   0002-1210-50
# 3  0002-1214_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-1214   0002-1214-04
# 4  0002-1340_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-1340   0002-1340-04
#
#                                   packagedescription  startmarketingdate  \
# 0             40 CAPSULE in 1 BOTTLE (0002-0604-40)           19560901.0
# 1  1 VIAL, MULTI-DOSE in 1 CAN (0002-1210-30)  / ...          20200528.0
# 2  1 VIAL, MULTI-DOSE in 1 CAN (0002-1210-50)  / ...          20200528.0
# 3  4 VIAL, SINGLE-DOSE in 1 CARTON (0002-1214-04)...          20240808.0
# 4  4 VIAL, SINGLE-DOSE in 1 CARTON (0002-1340-04)...          20240808.0
#
#    endmarketingdate ndc_exclude_flag sample_package
# ...

# %%
fda_excluded_product = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_excluded_product.csv"); fda_excluded_product.head()
# Out:
#                                         productid productndc  producttypename  \
# 0  0002-0604_043d7847-900a-48f5-8f08-a88d14645706  0002-0604              NaN
# 1  0002-1210_e82b7e9c-6569-415d-9498-084612225c12  0002-1210              NaN
# 2  0002-1407_3d42507b-6c2c-42ec-a8a2-a6e6a155e8c6  0002-1407              NaN
# 3  0002-1485_5879f620-a79a-468a-9eb5-da9b2bf6d584  0002-1485              NaN
# 4  0002-1975_39ce72df-8f3b-4db6-b450-d75351a05446  0002-1975              NaN
#
#        proprietaryname proprietarynamesuffix  nonproprietaryname  \
# 0            Seromycin                   NaN                 NaN
# 1               TAUVID                   NaN                 NaN
# 2  Quinidine Gluconate                   NaN                 NaN
# 3     Capastat sulfate                   NaN                 NaN
# 4               AXIRON                   NaN                 NaN
#
#    dosageformname  routename  startmarketingdate  endmarketingdate  \
# ...

# %%
fda_excluded_product.proprietaryname = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_excluded_product.proprietaryname.csv"); fda_excluded_product.proprietaryname.head()
# Out:
# 0              Seromycin
# 1                 TAUVID
# 2    Quinidine Gluconate
# 3       Capastat sulfate
# 4                 AXIRON
# Name: proprietaryname, dtype: object

# %%
fda_ndc_package = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_ndc_package.csv"); fda_ndc_package.head()
# Out:
#                                         productid productndc ndcpackagecode  \
# 0  0002-0152_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0152   0002-0152-01
# 1  0002-0152_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0152   0002-0152-04
# 2  0002-0213_458ef2aa-cd5f-48bc-8829-82420cfed33b  0002-0213   0002-0213-01
# 3  0002-0243_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0243   0002-0243-01
# 4  0002-0243_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0243   0002-0243-04
#
#                                   packagedescription  startmarketingdate  \
# 0  1 VIAL, SINGLE-DOSE in 1 CARTON (0002-0152-01)...            20240328
# 1  4 VIAL, SINGLE-DOSE in 1 CARTON (0002-0152-04)...            20240808
# 2  1 VIAL, MULTI-DOSE in 1 CARTON (0002-0213-01) ...            20230620
# 3  1 VIAL, SINGLE-DOSE in 1 CARTON (0002-0243-01)...            20240328
# 4  4 VIAL, SINGLE-DOSE in 1 CARTON (0002-0243-04)...            20240808
#
#    endmarketingdate ndc_exclude_flag sample_package
# ...

# %%
fda_ndc_product = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_ndc_product.csv"); fda_ndc_product.head()
# Out:
#                                         productid productndc  \
# 0  0002-0152_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0152
# 1  0002-0213_458ef2aa-cd5f-48bc-8829-82420cfed33b  0002-0213
# 2  0002-0243_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0243
# 3  0002-1152_333d2c1f-1a90-4b73-bf8a-85c7a9a0d21b  0002-1152
# 4  0002-1200_c2f899b5-287a-4002-ae37-f69418174eb4  0002-1200
#
#            producttypename proprietaryname proprietarynamesuffix  \
# 0  HUMAN PRESCRIPTION DRUG        Zepbound                   NaN
# 1           HUMAN OTC DRUG         Humulin                     R
# 2  HUMAN PRESCRIPTION DRUG        Zepbound                   NaN
# 3  HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 4  HUMAN PRESCRIPTION DRUG          Amyvid                   NaN
#
#   nonproprietaryname       dosageformname     routename  startmarketingdate  \
# 0        tirzepatide  INJECTION, SOLUTION  SUBCUTANEOUS            20231108
# ...

# %%
fda_ndc_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114434 entries, 0 to 114433
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   productid                         114434 non-null  object
#  1   productndc                        114434 non-null  object
#  2   producttypename                   114434 non-null  object
#  3   proprietaryname                   114412 non-null  object
#  4   proprietarynamesuffix             9249 non-null    object
#  5   nonproprietaryname                114430 non-null  object
#  6   dosageformname                    114434 non-null  object
#  7   routename                         112571 non-null  object
#  8   startmarketingdate                114434 non-null  int64
#  9   endmarketingdate                  3832 non-null    float64
#  10  marketingcategoryname             114434 non-null  object
# ...

# %%
# fda_ndc_product.proprietaryname = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_ndc_product.proprietaryname.csv"); fda_ndc_product.proprietaryname.head()

# %%
fda_unfinished_product = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_unfinished_product.csv"); fda_unfinished_product.head()
# Out:
#                                         productid productndc  \
# 0  0002-0013_15810e26-b479-41b8-9d13-9dc503a71a2a  0002-0013
# 1  0002-0095_15810e26-b479-41b8-9d13-9dc503a71a2a  0002-0095
# 2  0002-0096_15810e26-b479-41b8-9d13-9dc503a71a2a  0002-0096
# 3  0002-0113_55aa4078-e1e8-4338-b2b5-a9298b3c16e2  0002-0113
# 4  0002-0119_55aa4078-e1e8-4338-b2b5-a9298b3c16e2  0002-0119
#
#                producttypename nonproprietaryname         dosageformname  \
# 0  DRUG FOR FURTHER PROCESSING      Insulin human    INJECTION, SOLUTION
# 1  DRUG FOR FURTHER PROCESSING      Insulin human    INJECTION, SOLUTION
# 2  DRUG FOR FURTHER PROCESSING      Insulin human    INJECTION, SOLUTION
# 3  DRUG FOR FURTHER PROCESSING      Insulin human  INJECTION, SUSPENSION
# 4  DRUG FOR FURTHER PROCESSING      Insulin human  INJECTION, SUSPENSION
#
#    startmarketingdate  endmarketingdate        marketingcategoryname  \
# 0            19830627               NaN  DRUG FOR FURTHER PROCESSING
# ...

# %%
fda_unii = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.fda_unii.csv", low_memory=False); fda_unii.head()
# Out:
#          unii                        display_name           rn         ec  \
# 0  0001H6R5H1                   CEROUS SALICYLATE     526-17-0        NaN
# 1  000360VJE1     DI(DEHYDROABIETYL)AMINE ACETATE   53404-27-6        NaN
# 2  0005633KTU  SYMPHYOTRICHUM OBLONGIFOLIUM WHOLE          NaN        NaN
# 3  000705ZASD                        ADECATUMUMAB  503605-66-1        NaN
# 4  00072J7XWS                           GERMANIUM    7440-56-4  231-164-3
#
#      ncit   rxcui     pubchem     epa_comptox catalogue_of_life      itis  \
# 0     NaN     NaN  76966289.0  DTXSID90200572               NaN       NaN
# 1     NaN     NaN  76969106.0  DTXSID50109138               NaN       NaN
# 2     NaN     NaN         NaN             NaN             53Q8M  522228.0
# 3  C82358     NaN         NaN             NaN               NaN       NaN
# 4  C95170  4784.0   6326954.0   DTXSID8052483               NaN       NaN
#
#    ...            mpns  inn_id usan_id              mf  \
# ...

# %%
nadac = pd.read_csv(SAGERX_FOLDER + "/sagerx_lake.nadac.csv"); nadac.head()
# Out:
#                   ndc_description          ndc  nadac_per_unit effective_date  \
# 0  12HR NASAL DECONGEST ER 120 MG  24385005452         0.26838     2023-12-20
# 1  12HR NASAL DECONGEST ER 120 MG  70000047501         0.26838     2023-12-20
# 2  24H NASAL ALLERGY 55 MCG SPRAY  46122038576         0.76188     2023-12-20
# 3  24HR ALLERGY(LEVOCETIRZN) 5 MG  70000036201         0.20773     2023-12-20
# 4  24HR ALLERGY(LEVOCETIRZN) 5 MG  70000036202         0.20773     2023-12-20
#
#   pricing_unit pharmacy_type_indicator otc explanation_code  \
# 0           EA                     C/I   Y                1
# 1           EA                     C/I   Y                1
# 2           ML                     C/I   Y             1, 5
# 3           EA                     C/I   Y                1
# 4           EA                     C/I   Y                1
#
#   classifiation_for_rate_setting  corresponding_generic_drug_nadac_per_unit  \
# ...

# %% [markdown]
# !pip install psycopg2
