# %% [markdown]
# <a href="https://github.com/nghiencuuthuoc/PharmApp/PharmApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# ![](./images/PharmApp-logo.png)
# # PharmApp - Drug Discovery and Development
# Copyright 2024 | Nghiên Cứu Thuốc | RD_Pharma_Plus
#
# Email: nghiencuuthuoc@gmail.com | Web: nghiencuuthuoc.com | FB: facebook.com/nghiencuuthuoc | YouTube: youtube.com/@nghiencuuthuoc
#
# LinkedIN: linkedin.com/in/nghiencuuthuoc | Zalo: +84888999311 | WhatsAapp: +84888999311 | Twitter: x.com/nghiencuuthuoc

# %% [markdown]
# # Cosmeceutical Data Analysis

# %%
# import sys
# sys.path.append('..')
import os
# os.getcwd()
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd
import numpy as np
# pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df_hsk = pd.read_csv('thong_tin_san_pham_80.csv', on_bad_lines='skip', low_memory=False) # thay file thong_tin_san_pham_80.csv bằng file mình muốn tra
df_hsk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              80 non-null     int64
#  1   Mã sản phẩm             80 non-null     int64
#  2   Tên sản phẩm            80 non-null     object
#  3   Số công bố với Bộ Y Tế  24 non-null     object
#  4   Thông tin               80 non-null     object
#  5   Thông số                80 non-null     object
#  6   Thành phần              80 non-null     object
#  7   Cách dùng               80 non-null     object
#  8   Đánh giá                80 non-null     object
#  9   Hỏi đáp                 80 non-null     object
#  10  URL                     80 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 7.0+ KB

# %%
df_hsk = df_hsk.drop(["Unnamed: 0"], axis=1)
df_hsk.head()
# Out:
#    Unnamed: 0  Mã sản phẩm                                       Tên sản phẩm  \
# 0           0    422227714  [HSD 09/2025] Kem Xả Dove Serum 2in1 Tóc Phồng...
# 1           1    422219692  [HSD 02/2025] Nước Hoa Nữ Laura Anne Mystic Fo...
# 2           2    422211630         Dầu Gội Romano Hương Nước Hoa Classic 650g
# 3           3    422226382  [HSD 06/2025] Toner SVR Sebiaclear Dành Cho Da...
# 4           4    422225219  [HSD 07/2025] Gel Tẩy Tế Bào Chết Bio-essence ...
#
#   Số công bố với Bộ Y Tế                                          Thông tin  \
# 0                    NaN  Nội dung đang được cập nhật                   ...
# 1                    NaN  Nội dung đang được cập nhật                   ...
# 2         168/19/CBMP-BD  Dầu Gội Hương Nước Hoa Romano 650gr là dòng sả...
# 3                    NaN  Nội dung đang được cập nhật                   ...
# 4                    NaN  Nội dung đang được cập nhật                   ...
#
#                                             Thông số  \
# 0  Thông số sản phẩm\nBarcode\nThương Hiệu\nDove\...
# 1  Thông số sản phẩm\nBarcode\nThương Hiệu\nXuất ...
# 2  Thông số sản phẩm\nBarcode\n8935212810043\nThư...
# 3  Thông số sản phẩm\nBarcode\nThương Hiệu\nSVR\n...
# 4  Thông số sản phẩm\nBarcode\nThương Hiệu\nBio-e...
#
#                                          Thành phần  \
# 0                               Thành phần sản phẩm
# 1                               Thành phần sản phẩm
# 2  Thành phần sản phẩm\nNội dung đang được cập nhật
# 3                               Thành phần sản phẩm
# 4                               Thành phần sản phẩm
#
#                                            Cách dùng  \
# 0                                  Hướng dẫn sử dụng
# 1                                  Hướng dẫn sử dụng
# 2  Hướng dẫn sử dụng\nLàm ướt tóc.\nLấy một lượng...
# 3                                  Hướng dẫn sử dụng
# 4                                  Hướng dẫn sử dụng
#
#                                             Đánh giá  \
# 0  Đánh giá\nĐánh giá trung bình\n0.0\n0 nhận xét...
# 1  Đánh giá\nĐánh giá trung bình\n0.0\n0 nhận xét...
# 2  Đánh giá\nĐánh giá trung bình\n0.0\n0 nhận xét...
# 3  Đánh giá\nĐánh giá trung bình\n0.0\n0 nhận xét...
# 4  Đánh giá\nĐánh giá trung bình\n0.0\n0 nhận xét...
#
#                                  Hỏi đáp  \
# 0  Chưa có câu hỏi nào cho sản phẩm này.
# 1  Chưa có câu hỏi nào cho sản phẩm này.
# 2  Chưa có câu hỏi nào cho sản phẩm này.
# 3  Chưa có câu hỏi nào cho sản phẩm này.
# 4  Chưa có câu hỏi nào cho sản phẩm này.
#
#                                                  URL
# 0  https://hasaki.vn/san-pham/hsd-09-2025-kem-xa-...
# 1  https://hasaki.vn/san-pham/hsd-02-2025-nuoc-ho...
# 2  https://hasaki.vn/san-pham/dau-goi-romano-huon...
# 3  https://hasaki.vn/san-pham/hsd-06-2025-toner-s...
# 4  https://hasaki.vn/san-pham/hsd-07-2025-gel-tay...

# %%
from pandasgui import show
show(df_hsk)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI

# %%
def search(df: pd.DataFrame, substring: str, case: bool = False) -> pd.DataFrame: 
    mask = np.column_stack([df[col].astype(str).str.contains(substring.lower(), case=case, na=False) for col in df])
    return df.loc[mask.any(axis=1)]

# %%
# ingredient = str(input("Enter drug name: "))
ingredient = 'Hexanediol' # tra các sp có chứa Hexanediol

# %%
df_ingredient = search(df_hsk, ingredient)

# %%
df_ingredient
# Out:
#     Unnamed: 0  Mã sản phẩm  \
# 15          15    422215906
# 51          51    422206890
# 52          52    377400001
# 54          54    422222940
# 58          58    422224769
# 59          59    422209146
# 60          60    422216776
# 61          61    422219251
# 66          66    422216775
# 70          70    422215912
# 73          73    225200015
# 78          78    422215142
#
#                                          Tên sản phẩm Số công bố với Bộ Y Tế  \
# 15  Son Tint Lilybyred M12 Muscat Shower - Hồng Lạ...                    NaN
# 51       Dầu Gội Avatar Tinh Chất Bưởi Hà Thủ Ô 600ml                    NaN
# 52  Nước Tẩy Trang Derladie Ngừa Mụn, Hỗ Trợ Làm S...     105870/19/CBMP-QLD
# 54  Bảng Che Khuyết Điểm Judydoll 3 Màu - 02 Che Q...                    NaN
# 58  Xịt Khử Mùi Emmié Kháng Khuẩn Cho Vùng Kín & T...                    NaN
# 59  [Mini] Bộ Sản Phẩm Innisfree Dưỡng Ẩm Da Từ Tr...                    NaN
# 60  [Mini] Combo Serum innisfree Trà Xanh & Retino...                    NaN
# 61         Bộ innisfree Chăm Sóc Da Từ Trà Xanh 3 Món                    NaN
# 66  Bộ innisfree Dưỡng Ẩm, Làm Dịu, Phục Hồi Da 3 Món                    NaN
# 70  Son Tint Lilybyred Siêu Lì 07 Daring Cherry - ...                    NaN
# 73    Mặt Nạ Ngủ Môi Care:Nel Chiết Xuất Quả Mọng 23g     107341/19/CBMP-QLD
# 78                 [Mini] Bộ Dưỡng Da innisfree 2 Món                    NaN
#
#                                             Thông tin  \
# 15  Son Tint Lilybyred Glassy Layer Fixing Tint 3....
# 51  Dầu Gội AVATAR Tinh Chất Bưởi Hà Thủ Ô là dòng...
# 52  Nước Tẩy Trang Derladie Chiết Xuất Cây Phỉ là ...
# 54  Bảng Che Khyết Điểm Judydoll Moisturizing 3-Co...
# 58  Xịt Khử Mùi Emmié Intimate & Body Odor Spray K...
# 59  Combo innisfree Green Tea Trio Kit Dưỡng Ẩm Da...
# 60  Bộ Chăm Sóc Da innisfree Dưỡng Ẩm, Làm Dịu, Ph...
# 61  Bộ Chăm Sóc Da Trà Xanh innisfree hiện đã có t...
# 66  Bộ Chăm Sóc Da innisfree Dưỡng Ẩm, Làm Dịu, Ph...
# 70  Son Tint Lilybyred Bloody Liar Coating Tint Si...
# 73  Mặt Nạ Ngủ Môi CARE:NEL Lip Night Mask là dòng...
# 78  Bộ Sản Phẩm Dưỡng Da innisfree đã có tại Hasak...
#
#                                              Thông số  \
# 15  Thông số sản phẩm\nBarcode\n8809716940288\nThư...
# 51  Thông số sản phẩm\nBarcode\n8936183970712\nThư...
# 52  Thông số sản phẩm\nBarcode\n8809713360140\nThư...
# 54  Thông số sản phẩm\nBarcode\n6972786997666\nThư...
# 58  Thông số sản phẩm\nBarcode\n8938552514329\nThư...
# 59  Thông số sản phẩm\nBarcode\n8809843660455\nThư...
# 60  Thông số sản phẩm\nBarcode\n8809843684635\nThư...
# 61  Thông số sản phẩm\nBarcode\n8809843684628\nThư...
# 66  Thông số sản phẩm\nBarcode\n8809843684543\nThư...
# 70  Thông số sản phẩm\nBarcode\n8809716942121\nThư...
# 73  Thông số sản phẩm\nBarcode\n8809584960401\nThư...
# 78  Thông số sản phẩm\nBarcode\n8809843683546\nThư...
#
#                                            Thành phần  \
# 15  Thành phần sản phẩm\nWater, Diphenyl Dimethico...
# 51  Thành phần sản phẩm\nAqua, Citrus Grandis Peel...
# 52  Thành phần sản phẩm\nThành phần chính:\nChiết ...
# 54  Thành phần sản phẩm\nTriethylhexanoin, Dimethi...
# 58  Thành phần sản phẩm\nThành phần chính:\nHoa se...
# 59  Thành phần sản phẩm\nTinh Chất Trà Xanh Dưỡng ...
# 60  Thành phần sản phẩm\n1. Serum innisfree Green ...
# 61  Thành phần sản phẩm\n1. Serum innisfree Green ...
# 66  Thành phần sản phẩm\n1. Serum innisfree Green ...
# 70  Thành phần sản phẩm\nWater, Diisostearyl Malat...
# 73  Thành phần sản phẩm\nThành phần chi tiết:\nCAR...
# 78  Thành phần sản phẩm\n1. Tinh Chất innisfree Vi...
#
#                                             Cách dùng  \
# 15  Hướng dẫn sử dụng\nThoa một lượng son vừa đủ t...
# 51  Hướng dẫn sử dụng\nBước 1: Làm ướt tóc với nướ...
# 52  Hướng dẫn sử dụng\nCho nước tẩy trang ra bông ...
# 54  Hướng dẫn sử dụng\nChấm một lượng kem thích hợ...
# 58  Hướng dẫn sử dụng\nXịt lên vùng da dưới cánh t...
# 59  Hướng dẫn sử dụng\nTinh Chất Trà Xanh Dưỡng Ẩm...
# 60  Hướng dẫn sử dụng\n1. Serum innisfree Green Te...
# 61  Hướng dẫn sử dụng\n1. Serum innisfree Green Te...
# 66  Hướng dẫn sử dụng\n1. Serum innisfree Green Te...
# 70  Hướng dẫn sử dụng\nThoa một lượng son vừa đủ t...
# 73  Hướng dẫn sử dụng\nTrước khi đi ngủ bạn có thể...
# 78  Hướng dẫn sử dụng\n1. Tinh Chất innisfree Vita...
#
#                                              Đánh giá  \
# 15  Đánh giá\nĐánh giá trung bình\n5.0\n7 nhận xét...
# 51  Đánh giá\nĐánh giá trung bình\n4.6\n5 nhận xét...
# 52  Đánh giá\nĐánh giá trung bình\n4.6\n62 nhận xé...
# 54  Đánh giá\nĐánh giá trung bình\n0.0\n0 nhận xét...
# 58  Đánh giá\nĐánh giá trung bình\n0.0\n0 nhận xét...
# 59  Đánh giá\nĐánh giá trung bình\n0.0\n0 nhận xét...
# 60  Đánh giá\nĐánh giá trung bình\n0.0\n0 nhận xét...
# 61  Đánh giá\nĐánh giá trung bình\n0.0\n0 nhận xét...
# 66  Đánh giá\nĐánh giá trung bình\n5.0\n1 nhận xét...
# 70  Đánh giá\nĐánh giá trung bình\n5.0\n4 nhận xét...
# 73  Đánh giá\nĐánh giá trung bình\n4.8\n40 nhận xé...
# 78  Đánh giá\nĐánh giá trung bình\n0.0\n0 nhận xét...
#
#                                               Hỏi đáp  \
# 15  Hoa Bích - 02/08/2024\ncho em hỏi giá ở trên a...
# 51  Nhân Bùi - 25/07/2024\nCho hỏi nếu tóc bạc thì...
# 52  Hao - 12/04/2024\nsao loại mới nó vàng ngà ngà...
# 54              Chưa có câu hỏi nào cho sản phẩm này.
# 58              Chưa có câu hỏi nào cho sản phẩm này.
# 59  Chíp - 05/06/2023\nminh hỏi chai toner này là ...
# 60              Chưa có câu hỏi nào cho sản phẩm này.
# 61              Chưa có câu hỏi nào cho sản phẩm này.
# 66  Chị Trâm - 27/09/2024\nb ơi bộ này dùng cả sán...
# 70  Liên tran - 15/10/2024\nSon có trôi khi ăn uốn...
# 73  Hồng Phúc - 04/08/2024\nbôi mỗi ngày hay dùng ...
# 78              Chưa có câu hỏi nào cho sản phẩm này.
#
#                                                   URL
# 15  https://hasaki.vn/san-pham/son-tint-lilybyred-...
# 51  https://hasaki.vn/san-pham/dau-goi-avatar-tinh...
# 52  https://hasaki.vn/san-pham/nuoc-tay-trang-chie...
# 54  https://hasaki.vn/san-pham/bang-che-khyet-diem...
# 58  https://hasaki.vn/san-pham/xit-khu-mui-emmie-k...
# 59  https://hasaki.vn/san-pham/mini-bo-san-pham-in...
# 60  https://hasaki.vn/san-pham/gift-combo-serum-in...
# 61  https://hasaki.vn/san-pham/gift-bo-innisfree-c...
# 66  https://hasaki.vn/san-pham/bo-innisfree-duong-...
# 70  https://hasaki.vn/san-pham/son-tint-lilybyred-...
# 73  https://hasaki.vn/san-pham/mat-na-ngu-moi-care...
# 78  https://hasaki.vn/san-pham/gift-bo-san-pham-in...

# %%
df_ingredient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 24 to 84
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    26 non-null     int64
#  1   Tên sản phẩm  26 non-null     object
#  2   Thông tin     26 non-null     object
#  3   Thông số      26 non-null     object
#  4   Thành phần    26 non-null     object
#  5   Cách dùng     26 non-null     object
#  6   Đánh giá      26 non-null     object
#  7   Hỏi đáp       26 non-null     object
#  8   URL           26 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 2.0+ KB

# %%
from pandasgui import show
show(df_ingredient) # tra các sp có chứa Hexanediol
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI

# %%
ingredient = str(input("Enter drug name: ")) # ví dụ nhập Germanium
df_ingredient = search(df_hsk, ingredient)
df_ingredient.head()
# Out:
# Enter drug name:  Germanium
# Empty DataFrame
# Columns: [Unnamed: 0, Mã sản phẩm, Tên sản phẩm, Số công bố với Bộ Y Tế, Thông tin, Thông số, Thành phần, Cách dùng, Đánh giá, Hỏi đáp, URL]
# Index: []

# %%
from pandasgui import show
show(df_ingredient)

# %%
Xin cảm ơn
