# %% [markdown]
# <table align="center">
#   <td>
#     <a href="https://colab.research.google.com/github/nghiencuuthuoc/PharmApp/PharmApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/nghiencuuthuoc/PharmApp/blob/master/PharmApp.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>
#
#
# ![](./images/PharmApp-logo.png)
# # PharmApp - Drug Discovery and Development
# Copyright 2024 | Nghiên Cứu Thuốc | RD_Pharma_Plus
#
# Email: nghiencuuthuoc@gmail.com | Web: nghiencuuthuoc.com | FB: facebook.com/nghiencuuthuoc | YouTube: youtube.com/@nghiencuuthuoc
#
# LinkedIn: linkedin.com/in/nghiencuuthuoc | Zalo: +84888999311 | WhatsApp: +84888999311 | Twitter: x.com/nghiencuuthuoc

# %% [markdown]
# # Inactive Ingredients Database FDA
# The Inactive Ingredients files are supplied as comma delimited text and Excel files. The size of each unzipped file is less than 2 MB.
#
# We update the database quarterly.
#
# ### [Download here](https://www.fda.gov/drugs/drug-approvals-and-databases/inactive-ingredients-database-download)

# %% [markdown]
# ### [Inactive Ingredients in Approved Drug Products Search: Frequently Asked Questions](https://www.fda.gov/drugs/drug-approvals-and-databases/inactive-ingredients-approved-drug-products-search-frequently-asked-questions)

# %%
import sys
sys.path.append('..')
import pandas as pd
import os
os.getcwd()
# Out:
# 'D:\\PharmApp\\notebook'

# %%
drug_name = 'vyloy'

# %%
iig_file = drug_name + "_inactive_ingredient_list.txt"
iig_file_path = os.path.join('../iigdata', iig_file)

if os.path.isfile(iig_file_path):
    df_iig = pd.read_csv(iig_file_path)
    df_inactive = df_iig.drop('NDC', axis=1).drop('MainDrug', axis=1).drop('Strength', axis=1).drop('Formulation', axis=1)
    df_inactive = df_inactive.drop_duplicates()
    df_inactive
else:
    print(f'{drug_name} not exist')

# %%
df_inactive
# Out:
#           Inactive        UNII
# 0         ARGININE  94ZLA3W45F
# 1          SUCROSE  C151H8M554
# 2   POLYSORBATE 80  6OZP39ZG8H
# 3  PHOSPHORIC ACID  E4GA8884NN

# %%
df_inactive_ingredients =  pd.read_csv('../inactive_ingredients/IIR_OCOMM.csv')
df_inactive_ingredients
# Out:
#          INGREDIENT_NAME        ROUTE                        DOSAGE_FORM  \
# 0      .ALPHA.-TERPINEOL      TOPICAL                             LOTION
# 1     .ALPHA.-TOCOPHEROL       BUCCAL                      FILM, SOLUBLE
# 2     .ALPHA.-TOCOPHEROL  INTRAVENOUS  INJECTION, POWDER, FOR SUSPENSION
# 3     .ALPHA.-TOCOPHEROL         ORAL                            CAPSULE
# 4     .ALPHA.-TOCOPHEROL         ORAL                           SOLUTION
# ...                  ...          ...                                ...
# 9305       ZINC STEARATE      TOPICAL                              CREAM
# 9306       ZINC STEARATE      TOPICAL                           OINTMENT
# 9307       ZINC STEARATE      TOPICAL                             POWDER
# 9308       ZINC STEARATE      TOPICAL                            SHAMPOO
# 9309        ZINC SULFATE      VAGINAL                             DOUCHE
#
#       CAS_NUMBER        UNII  POTENCY_AMOUNT POTENCY_UNIT  \
# ...

# %%
df.loc[df['B'].isin(['one','three'])])

# %%
df_filter = df_inactive_ingredients
df = df_inactive_ingredients

# %%
df_filter = df_filter.loc[df['ROUTE'] == 'ORAL']
df_filter = df_filter.loc[df['DOSAGE_FORM'] == 'TABLET']
df_filter
# Out:
#                     INGREDIENT_NAME ROUTE DOSAGE_FORM  CAS_NUMBER        UNII  \
# 5                .ALPHA.-TOCOPHEROL  ORAL      TABLET   1406184.0  H4N855PNZ1
# 13       .ALPHA.-TOCOPHEROL ACETATE  ORAL      TABLET   7695912.0  9E8X80D2L0
# 21          .ALPHA.-TOCOPHEROL, DL-  ORAL      TABLET  10191410.0  7QWA1RIO01
# 27    1-(PHENYLAZO)-2-NAPHTHYLAMINE  ORAL      TABLET     85847.0  3VSI4D701X
# 50                           ACACIA  ORAL      TABLET   9000015.0  5C5403N26O
# ...                             ...   ...         ...         ...         ...
# 9261                        XYLITOL  ORAL      TABLET     87990.0  VCQ006KQ1E
# 9270                     YELLOW WAX  ORAL      TABLET   8012893.0  2ZA36H0S2V
# 9277                           ZEIN  ORAL      TABLET   9010666.0  80N308T1NN
# 9289                  ZINC CHLORIDE  ORAL      TABLET   7646857.0  86Q357L16B
# 9300                  ZINC STEARATE  ORAL      TABLET    557051.0  H92E6QA4FV
#
# ...

# %%
df_filter = df[df['ROUTE'].str.contains("ORAL")]
df_filter = df[df['DOSAGE_FORM'].str.contains("TABLET")]
df_filter
# Out:
#                  INGREDIENT_NAME       ROUTE               DOSAGE_FORM  \
# 5             .ALPHA.-TOCOPHEROL        ORAL                    TABLET
# 6             .ALPHA.-TOCOPHEROL        ORAL          TABLET, CHEWABLE
# 7             .ALPHA.-TOCOPHEROL        ORAL  TABLET, EXTENDED RELEASE
# 8             .ALPHA.-TOCOPHEROL        ORAL       TABLET, FILM COATED
# 13    .ALPHA.-TOCOPHEROL ACETATE        ORAL                    TABLET
# ...                          ...         ...                       ...
# 9300               ZINC STEARATE        ORAL                    TABLET
# 9301               ZINC STEARATE        ORAL            TABLET, COATED
# 9302               ZINC STEARATE        ORAL  TABLET, EXTENDED RELEASE
# 9303               ZINC STEARATE        ORAL       TABLET, FILM COATED
# 9304               ZINC STEARATE  SUBLINGUAL                    TABLET
#
#       CAS_NUMBER        UNII  POTENCY_AMOUNT POTENCY_UNIT  \
# ...

# %%
df_dosage_form = df_inactive_ingredients.drop('INGREDIENT_NAME', axis=1).drop('CAS_NUMBER', axis=1).drop('UNII', axis=1).drop('POTENCY_AMOUNT', axis=1).drop('POTENCY_UNIT', axis=1).drop('MAXIMUM_DAILY_EXPOSURE', axis=1).drop('MAXIMUM_DAILY_EXPOSURE_UNIT', axis=1).drop('RECORD_UPDATED', axis=1).drop('ROUTE', axis=1)
df_dosage_form = df_dosage_form.drop_duplicates()
df_dosage_form.head()
# Out:
#                          DOSAGE_FORM
# 0                             LOTION
# 1                      FILM, SOLUBLE
# 2  INJECTION, POWDER, FOR SUSPENSION
# 3                            CAPSULE
# 4                           SOLUTION

# %%
df_dosage_form['DOSAGE_FORM'] = total_rows['ColumnID'].astype(str)

# %%
df_route = df_inactive_ingredients.drop('INGREDIENT_NAME', axis=1).drop('CAS_NUMBER', axis=1).drop('UNII', axis=1).drop('POTENCY_AMOUNT', axis=1).drop('POTENCY_UNIT', axis=1).drop('MAXIMUM_DAILY_EXPOSURE', axis=1).drop('MAXIMUM_DAILY_EXPOSURE_UNIT', axis=1).drop('RECORD_UPDATED', axis=1).drop('DOSAGE_FORM', axis=1)
df_route = df_route.drop_duplicates()
df_route.head()
# Out:
#           ROUTE
# 0       TOPICAL
# 1        BUCCAL
# 2   INTRAVENOUS
# 3          ORAL
# 25  TRANSDERMAL
