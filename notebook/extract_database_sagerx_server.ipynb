# %% [markdown]
# <a href="https://github.com/nghiencuuthuoc/PharmApp/PharmApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# ![](./images/PharmApp-logo.png)
# # PharmApp - Research and Development Pharmaceuticals
# Copyright 2024 | Nghiên Cứu Thuốc | RD_Pharma_Plus
#
# Email: nghiencuuthuoc@gmail.com | nghiencuuthuoc.com | x.com/nghiencuuthuoc | facebook.com/nghiencuuthuoc

# %% [markdown]
# ## Connect to psql

# %%
import sys
sys.path.append('..')
# import os
# os.getcwd()

# %%
# SAGERX_FOLDER = '../sagerxdata'

# %% [markdown]
# ## all_tables

# %%
table_name = 'all_tables'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = 'SELECT * FROM pg_catalog.pg_tables'
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
all_tables = pd.read_csv(path_csv_file, low_memory=False)
sagerx_lake_tables = all_tables[all_tables["schemaname"] == 'sagerx_lake']
sagerx_lake_tables = sagerx_lake_tables.drop(['tableowner','tablespace', 'hasindexes','hastriggers', 'rowsecurity', 'hasrules'], axis=1)
sagerx_lake_tables = sagerx_lake_tables.set_axis(range(len(sagerx_lake_tables)))
sagerx_lake_tables
# Out:
#      schemaname                   tablename
# 0   sagerx_lake             dailymed_rxnorm
# 1   sagerx_lake                    fda_unii
# 2   sagerx_lake  dailymed_zip_file_metadata
# 3   sagerx_lake      rxclass_atc_to_product
# 4   sagerx_lake                       nadac
# 5   sagerx_lake        rxnorm_rxncuichanges
# 6   sagerx_lake      fda_unfinished_product
# 7   sagerx_lake        dailymed_pharm_class
# 8   sagerx_lake           rxnorm_historical
# 9   sagerx_lake               rxnorm_rxnsat
# 10  sagerx_lake      fda_unfinished_package
# 11  sagerx_lake              dailymed_daily
# 12  sagerx_lake        fda_excluded_product
# 13  sagerx_lake        fda_excluded_package
# 14  sagerx_lake                     rxterms
# 15  sagerx_lake         rxterms_ingredients
# 16  sagerx_lake      orange_book_exlusivity
# 17  sagerx_lake        orange_book_products
# 18  sagerx_lake          orange_book_patent
# 19  sagerx_lake                 purple_book
# 20  sagerx_lake             fda_enforcement
# 21  sagerx_lake               rxnorm_rxncui
# 22  sagerx_lake               rxnorm_rxnsty
# 23  sagerx_lake             rxnorm_rxnconso
# 24  sagerx_lake       rxnorm_rxnatomarchive
# 25  sagerx_lake               rxnorm_rxnsab
# 26  sagerx_lake               rxnorm_rxndoc
# 27  sagerx_lake               rxnorm_rxnrel
# 28  sagerx_lake             fda_ndc_product
# 29  sagerx_lake             fda_ndc_package

# %%
sagerx_tables = all_tables[all_tables["schemaname"] == 'sagerx']
sagerx_tables = sagerx_tables.drop(['tableowner','tablespace', 'hasindexes','hastriggers', 'rowsecurity', 'hasrules'], axis=1)
sagerx_tables = sagerx_tables.set_axis(range(len(sagerx_tables)))
sagerx_tables
# Out:
#   schemaname                   tablename
# 0     sagerx           data_availability
# 1     sagerx  dailymed_organization_text
# 2     sagerx        dailymed_interaction

# %% [markdown]
# ## dailymed_interaction

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx'
table_name = 'dailymed_interaction'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
dailymed_interaction = pd.read_csv(path_csv_file, low_memory=False)
dailymed_interaction
# Out:
#                                                spl  \
# 0    20240824_2ec2afa8-f91a-46cd-ac4e-b8ffa59015ec
# 1    20240824_e1166b3a-a304-4030-ab51-eb55c6e91afd
# 2    20240824_1dbd8448-c1e5-46df-8060-50ef82380445
# 3    20240824_fd4eaf3f-ef9c-4615-9438-a95d91feee06
# 4    20240824_3ba957ea-28ed-4a61-a318-98064ea4944d
# ..                                             ...
# 267  20240907_bc751403-94f2-4f9d-b533-cf6186a40ceb
# 268  20240907_6a104328-3208-4157-be60-8fdc907d3825
# 269  20240907_19816051-c25e-44b5-a127-e846dbd0a8d8
# 270  20240907_3ecff825-34ea-4535-b935-627bf2c13d93
# 271  20240907_ef3b5cbe-f9e1-c1ac-79da-cfe14e3a7e7e
#
#                               document_id  \
# 0    205ba6f0-3a28-153f-e063-6294a90ab9e2
# 1    e1166b3a-a304-4030-ab51-eb55c6e91afd
# 2    20536f36-1759-8026-e063-6394a90a5103
# 3    205c08c9-a5cd-defb-e063-6294a90a8c3b
# 4    3ac3297d-40ef-488c-bca7-17542d1de0d0
# ..                                    ...
# 267  3f4053b8-3168-4e3b-8257-50bc28c3b58f
# 268  21775d76-4082-e05a-e063-6394a90a2a67
# 269  21587ffd-a2a5-f093-e063-6394a90a6658
# 270  21706a21-fd4b-07a0-e063-6294a90adbbc
# 271  fe4c241c-e545-b24f-818d-53716a837925
#
#                                    set_id  version_number  \
# 0    2ec2afa8-f91a-46cd-ac4e-b8ffa59015ec               9
# 1    e1166b3a-a304-4030-ab51-eb55c6e91afd               1
# 2    1dbd8448-c1e5-46df-8060-50ef82380445              15
# 3    fd4eaf3f-ef9c-4615-9438-a95d91feee06               6
# 4    3ba957ea-28ed-4a61-a318-98064ea4944d               4
# ..                                    ...             ...
# 267  bc751403-94f2-4f9d-b533-cf6186a40ceb               9
# 268  6a104328-3208-4157-be60-8fdc907d3825               8
# 269  19816051-c25e-44b5-a127-e846dbd0a8d8               1
# 270  3ecff825-34ea-4535-b935-627bf2c13d93               1
# 271  ef3b5cbe-f9e1-c1ac-79da-cfe14e3a7e7e               9
#
#                                       interaction_text
# 0    \r\n                     \r\n                 ...
# 1                                                  NaN
# 2    \r\n                     \r\n                 ...
# 3    \r\n               \r\n               \r\n    ...
# 4    \r\n               \r\n               \r\n    ...
# ..                                                 ...
# 267  \r\n                     \r\n                 ...
# 268  \r\n               \r\n               \r\n    ...
# 269  \r\n               \r\n               \r\n    ...
# 270  \r\n               \r\n               \r\n    ...
# 271  \r\n               \r\n               \r\n    ...
#
# [272 rows x 5 columns]

# %% [markdown]
# ## dailymed_organization_text

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx'
table_name = 'dailymed_organization_text'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
dailymed_organization_text = pd.read_csv(path_csv_file, low_memory=False)
dailymed_organization_text
# Out:
#                                                spl  \
# 0    20240824_05b076d9-6516-4538-8e05-9709a677ed2f
# 1    20240824_07361f0e-90c7-4531-8d3f-1ec5e7fed40d
# 2    20240824_077bb160-e616-4863-bdde-989140f99e1c
# 3    20240824_102c3893-4fdc-40b3-bd83-775e292723d7
# 4    20240824_1466c070-9f97-4fa4-a955-6a6b59981fb8
# ..                                             ...
# 469  20240907_ef58f422-682e-6896-e053-2a95a90a1f2d
# 470  20240907_f42139aa-bb38-4791-b41e-cd8f2c922529
# 471  20240907_f9f56326-6d72-47d3-89ac-3625b8a6d713
# 472  20240907_fbc05ceb-2e69-3c37-e053-6394a90ac4f4
# 473  20240907_fd569104-8243-48fa-8e93-5a08654ad6dd
#
#                               document_id  \
# 0    ddf1d2bb-b32a-4fb1-9e0e-1b3047c9b448
# 1    0cdb0e0b-0f75-403d-a2b7-0386db8ffee5
# 2    e5c1db20-4893-4dc8-b577-a649ab230c8c
# 3    64a7bb93-6461-45c9-b5ca-610a25db5140
# 4    20601ee5-87ad-6842-e063-6294a90a16ea
# ..                                    ...
# 469  217adc8e-b886-1fdb-e063-6294a90a26fa
# 470  28f00631-ce3c-47b8-bd77-459f3139a4f2
# 471  f9f56326-6d72-47d3-89ac-3625b8a6d713
# 472  217602a6-c79c-2d9e-e063-6394a90a63ea
# 473  6734c51a-561d-4c16-acbc-c33e4bf8ede6
#
#                                    set_id  \
# 0    05b076d9-6516-4538-8e05-9709a677ed2f
# 1    07361f0e-90c7-4531-8d3f-1ec5e7fed40d
# 2    077bb160-e616-4863-bdde-989140f99e1c
# 3    102c3893-4fdc-40b3-bd83-775e292723d7
# 4    1466c070-9f97-4fa4-a955-6a6b59981fb8
# ..                                    ...
# 469  ef58f422-682e-6896-e053-2a95a90a1f2d
# 470  f42139aa-bb38-4791-b41e-cd8f2c922529
# 471  f9f56326-6d72-47d3-89ac-3625b8a6d713
# 472  fbc05ceb-2e69-3c37-e053-6394a90ac4f4
# 473  fd569104-8243-48fa-8e93-5a08654ad6dd
#
#                                      organization_text  row_num
# 0    \r\n                  Inform patients to take ...        1
# 1    \r\n                        In the presence of...        1
# 2    \r\n                  Central Nervous System (...        1
# 3    \r\n                  Dispense with Medication...        1
# 4    \r\n                  \r\n                    ...        1
# ..                                                 ...      ...
# 469  \r\n                  \r\n                    ...        1
# 470  \r\n                  \r\n                    ...        1
# 471  \r\n                  \r\n                    ...        1
# 472  \r\n                  Gabapentin Tablets, USP\...        1
# 473  \r\n                  \r\n                    ...        1
#
# [474 rows x 5 columns]

# %% [markdown]
# ## data_availability

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx'
table_name = 'data_availability'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
data_availability = pd.read_csv(path_csv_file, low_memory=False)
data_availability
# Out:
# Empty DataFrame
# Columns: [schema_name, table_name, has_data, materialized]
# Index: []

# %% [markdown]
# ## dailymed_daily

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'dailymed_daily'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
dailymed_daily = pd.read_csv(path_csv_file, low_memory=False)
dailymed_daily
# Out:
#                                                spl  \
# 0    20240824_2ec2afa8-f91a-46cd-ac4e-b8ffa59015ec
# 1    20240824_e1166b3a-a304-4030-ab51-eb55c6e91afd
# 2    20240824_1dbd8448-c1e5-46df-8060-50ef82380445
# 3    20240824_fd4eaf3f-ef9c-4615-9438-a95d91feee06
# 4    20240824_3ba957ea-28ed-4a61-a318-98064ea4944d
# ..                                             ...
# 267  20240907_bc751403-94f2-4f9d-b533-cf6186a40ceb
# 268  20240907_6a104328-3208-4157-be60-8fdc907d3825
# 269  20240907_19816051-c25e-44b5-a127-e846dbd0a8d8
# 270  20240907_3ecff825-34ea-4535-b935-627bf2c13d93
# 271  20240907_ef3b5cbe-f9e1-c1ac-79da-cfe14e3a7e7e
#
#                                     file_name  \
# 0    205ba6f0-3a28-153f-e063-6294a90ab9e2.xml
# 1    e1166b3a-a304-4030-ab51-eb55c6e91afd.xml
# 2    20536f36-1759-8026-e063-6394a90a5103.xml
# 3    205c08c9-a5cd-defb-e063-6294a90a8c3b.xml
# 4    3ac3297d-40ef-488c-bca7-17542d1de0d0.xml
# ..                                        ...
# 267  3f4053b8-3168-4e3b-8257-50bc28c3b58f.xml
# 268  21775d76-4082-e05a-e063-6394a90a2a67.xml
# 269  21587ffd-a2a5-f093-e063-6394a90a6658.xml
# 270  21706a21-fd4b-07a0-e063-6294a90adbbc.xml
# 271  fe4c241c-e545-b24f-818d-53716a837925.xml
#
#                                            xml_content
# 0    <dailymed>\r\n  <documentId>205ba6f0-3a28-153f...
# 1    <dailymed>\r\n  <documentId>e1166b3a-a304-4030...
# 2    <dailymed>\r\n  <documentId>20536f36-1759-8026...
# 3    <dailymed>\r\n  <documentId>205c08c9-a5cd-defb...
# 4    <dailymed>\r\n  <documentId>3ac3297d-40ef-488c...
# ..                                                 ...
# 267  <dailymed>\r\n  <documentId>3f4053b8-3168-4e3b...
# 268  <dailymed>\r\n  <documentId>21775d76-4082-e05a...
# 269  <dailymed>\r\n  <documentId>21587ffd-a2a5-f093...
# 270  <dailymed>\r\n  <documentId>21706a21-fd4b-07a0...
# 271  <dailymed>\r\n  <documentId>fe4c241c-e545-b24f...
#
# [272 rows x 3 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'dailymed_pharm_class'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
dailymed_pharm_class = pd.read_csv(path_csv_file, low_memory=False)
dailymed_pharm_class
# Out:
#                                   spl_setid  spl_version  \
# 0      000155a8-709c-44e5-a75f-cd890f3a7caf           29
# 1      0002ad27-779d-42ab-83b5-bc65453412a1           25
# 2      0002eded-a283-4590-a78c-b6ff2027e684            1
# 3      0003458f-352a-46fa-9d99-230daa76ae29           10
# 4      0003eccd-6147-4a7c-ae83-b2a94933e07d            7
# ...                                     ...          ...
# 91589  fff6f057-739e-40f1-8427-e1364c65af05            1
# 91590  fff9089f-ac8e-40b4-8f44-d8e3d2d4200e           10
# 91591  fff96669-4157-4517-906e-a9be0b44be1f            2
# 91592  fffa5d75-0dba-4ad7-a252-5f60fa28489a            8
# 91593  fffebd01-3815-425f-8293-1ad909d0d0ab            1
#
#                                pharma_setid  pharma_version
# 0      c29a4f1b-49e6-46a6-aefe-820474b74d5f               2
# 1      02f4926a-415c-4085-b6be-417f20cc1d71               2
# 2      ff3fd145-6f50-4a4d-ac9d-5f277860bf91               4
# 3      03e2633d-120e-47dc-95a0-03c4d9c1e077               2
# 4      ec138ad1-672f-4eaf-8b27-aa99ef213fa2               2
# ...                                     ...             ...
# 91589  7d0a8797-d20d-43ca-8a4c-9abbbe2d2c7d               2
# 91590  6993a44d-c30f-420e-98ce-0b0945801c89               2
# 91591  5d32c293-c333-44a9-a442-04cc23ccc70b               2
# 91592  6eb52f25-1a2a-4880-bda9-6ebd2e765870               2
# 91593  b061d6f4-2ff0-4446-8046-8c7fa2e04d8c               3
#
# [91594 rows x 4 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'dailymed_rxnorm'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
dailymed_rxnorm = pd.read_csv(path_csv_file, low_memory=False)
dailymed_rxnorm
# Out:
#                                         setid  spl_version    rxcui  \
# 0        0001d1cf-f727-4875-a44f-5a51f7b617a4            2  1046593
# 1        0001d1cf-f727-4875-a44f-5a51f7b617a4            2  1046593
# 2        0001d1cf-f727-4875-a44f-5a51f7b617a4            2  1046593
# 3        0001d1cf-f727-4875-a44f-5a51f7b617a4            2  1046593
# 4        0001eaa9-e890-4e94-9d44-47a0f3086a02            2   251577
# ...                                       ...          ...      ...
# 460309  le72300d9-89b4-48c7-98a5-ea5d7772305e            1   209011
# 460310  lf69f100f-c766-490f-9143-5e8e0c8cb7c9            1   836358
# 460311  lf69f100f-c766-490f-9143-5e8e0c8cb7c9            1   836358
# 460312  lf69f100f-c766-490f-9143-5e8e0c8cb7c9            1   836358
# 460313  lf69f100f-c766-490f-9143-5e8e0c8cb7c9            1   836358
#
#                                                     rxstr rxtty
# 0       benzalkonium chloride 0.13 % Medicated Liquid ...   PSN
# 1       benzalkonium chloride 0.13 % Medicated Liquid ...    SY
# 2       benzalkonium chloride 1.3 MG/ML Medicated Liqu...   SCD
# 3       benzalkonium chloride 1.33 MG/ML Medicated Liq...    SY
# 4                     salicylic acid 2 % Topical Solution   PSN
# ...                                                   ...   ...
# 460309        calcium acetate 667 MG Oral Tablet [Phoslo]   SBD
# 460310     ipratropium bromide 0.02 % Inhalation Solution   PSN
# 460311     ipratropium bromide 0.02 % Inhalation Solution    SY
# 460312  ipratropium bromide 0.2 MG/ML Inhalation Solution   SCD
# 460313  ipratropium bromide 0.5 MG per 2.5 ML Inhalati...    SY
#
# [460314 rows x 5 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'dailymed_zip_file_metadata'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
dailymed_zip_file_metadata = pd.read_csv(path_csv_file, low_memory=False)
dailymed_zip_file_metadata
# Out:
#                                        setid  \
# 0       a661a6c8-0eb3-0b28-e053-2a95a90a66fe
# 1       94d13f48-fbca-67b4-e053-2995a90a791b
# 2       25500fd1-4fee-43db-9c71-45912594fe06
# 3       7508ce57-40bc-4d50-8025-44d28bfc2ccb
# 4       a338f711-734c-07d3-e053-2a95a90aed79
# ...                                      ...
# 151173  ce949b74-c0cd-4f9e-9a4a-04043ed7121e
# 151174  d304ffec-1a94-426f-89c7-e4c8e77be15c
# 151175  d7efce0d-4259-43ea-9224-55c2d54a14dc
# 151176  ea0c9867-3299-46c9-995e-322af53f0519
# 151177  f435e79d-dea3-49dc-8268-146c60ba52a1
#
#                                             zip_file_name upload_date  \
# 0       20200524_a661a6c8-0eb3-0b28-e053-2a95a90a66fe.zip  05/26/2020
# 1       20240131_94d13f48-fbca-67b4-e053-2995a90a791b.zip  01/31/2024
# 2       20091231_25500fd1-4fee-43db-9c71-45912594fe06.zip  10/09/2010
# 3       20091231_7508ce57-40bc-4d50-8025-44d28bfc2ccb.zip  10/09/2010
# 4       20200419_a338f711-734c-07d3-e053-2a95a90aed79.zip  04/20/2020
# ...                                                   ...         ...
# 151173  20130221_ce949b74-c0cd-4f9e-9a4a-04043ed7121e.zip  02/21/2013
# 151174  20150521_d304ffec-1a94-426f-89c7-e4c8e77be15c.zip  05/21/2015
# 151175  20130520_d7efce0d-4259-43ea-9224-55c2d54a14dc.zip  05/21/2013
# 151176  20130327_ea0c9867-3299-46c9-995e-322af53f0519.zip  03/27/2013
# 151177  20150522_f435e79d-dea3-49dc-8268-146c60ba52a1.zip  05/22/2015
#
#         spl_version                                              title
# 0                 1  (BIOTEMED) INSTANT HAND SANITIZER (ALCOHOL) GE...
# 1                 4  (CHLOROPROCAINE HCI INJECTION, SOLUTION [HF AC...
# 2                 1  (DEODORANT PLUS ANTIPERSPIRANT) STICK [RAANI C...
# 3                 1  (DEODORANT PLUS ANTIPERSPIRANT) STICK [RAANI C...
# 4                 3  (ETHANOL62%) DR KEEPS GEL (ETHANOL) (ALCOHOL) ...
# ...             ...                                                ...
# 151173            2                                   NOT A DRUG LABEL
# 151174            6                                   NOT A DRUG LABEL
# 151175            3                                   NOT A DRUG LABEL
# 151176            1                                   NOT A DRUG LABEL
# 151177            7                                   NOT A DRUG LABEL
#
# [151178 rows x 5 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'fda_enforcement'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
fda_enforcement = pd.read_csv(path_csv_file, low_memory=False)
fda_enforcement
# Out:
#        index      status                           city state        country  \
# 0          0     Ongoing                      Hawthorne    NY  United States
# 1          1     Ongoing  Aurangabad, Maharashtra State   NaN          India
# 2          2     Ongoing                       Somerset    NJ  United States
# 3          3     Ongoing                       Manassas    VA  United States
# 4          4     Ongoing                        Houston    TX  United States
# ...      ...         ...                            ...   ...            ...
# 16407  16407     Ongoing                        Waltham    MA  United States
# 16408  16408     Ongoing                        Yonkers    NY  United States
# 16409  16409   Completed                       New York    NY  United States
# 16410  16410  Terminated                      La Vergne    TN  United States
# 16411  16411     Ongoing                     Parsippany    NJ  United States
#
#       classification                                            openfda  \
# 0          Class III                                                 {}
# 1           Class II  {"application_number": ["ANDA077259"], "brand_...
# 2          Class III  {"application_number": ["ANDA090145"], "brand_...
# 3          Class III                                                 {}
# 4           Class II                                                 {}
# ...              ...                                                ...
# 16407       Class II  {"application_number": ["NDA020171"], "brand_n...
# 16408       Class II  {"brand_name": ["STELLALIFE VEGA ORAL CARE"], ...
# 16409       Class II  {"application_number": ["NDA018916"], "brand_n...
# 16410        Class I                                                 {}
# 16411       Class II  {"application_number": ["ANDA065205"], "brand_...
#
#       product_type  event_id  \
# 0            Drugs     95125
# 1            Drugs     94990
# 2            Drugs     94924
# 3            Drugs     94981
# 4            Drugs     95079
# ...            ...       ...
# 16407        Drugs     93690
# 16408        Drugs     92453
# 16409        Drugs     91379
# 16410        Drugs     93224
# 16411        Drugs     94750
#
#                                           recalling_firm  ... recall_number  \
# 0                      Taro Pharmaceuticals U.S.A., Inc.  ...   D-0633-2024
# 1                                            FDC Limited  ...   D-0632-2024
# 2          Novel Laboratories, Inc. d.b.a Lupin Somerset  ...   D-0628-2024
# 3                          Granules Consumer Health Inc.  ...   D-0627-2024
# 4                            EMPOWER CLINIC SERVICES LLC  ...   D-0630-2024
# ...                                                  ...  ...           ...
# 16407              Fresenius Medical Care Holdings, Inc.  ...   D-0218-2024
# 16408                       Homeocare Laboratories, Inc.  ...   D-0890-2023
# 16409                                        Pfizer Inc.  ...   D-0097-2023
# 16410  The Harvard Drug Group LLC dba Major Pharmaceu...  ...   D-0153-2024
# 16411                      Teva Pharmaceuticals USA, Inc  ...   D-0561-2024
#
#                                      product_description  \
# 0      Hydrocortisone 1% & Acetic Acid 2% Otic Soluti...
# 1      Timolol Maleate Ophthalmic Solution USP, 0.5%,...
# 2      PEG-3350, Sodium Sulfate, Sodium Chloride, Pot...
# 3      Acetaminophen, USP 500mg, Pain Reliever/Fever ...
# 4      Empower Pharmacy, Estradiol Cypionate Injectio...
# ...                                                  ...
# 16407  DELFLEX Peritoneal Dialysis Solution in Biofin...
# 16408  StellaLife VEGA Oral Care Gel, 1 fl oz (30 ml)...
# 16409  Heparin Sodium 2,000, USP Units, per 1,000 mL ...
# 16410  Phenytoin Oral Suspension, USP, 100 mg/4 mL, p...
# 16411  Amoxicillin and Clavulanate Potassium Tablets ...
#
#              product_quantity  \
# 0                    96 vials
# 1             362,544 bottles
# 2              13,200 cartons
# 3              21,192 Bottles
# 4                       2,797
# ...                       ...
# 16407             69,590 bags
# 16408  33,109/1 fl. oz. tubes
# 16409             62,088 bags
# 16410     3718 saleable units
# 16411          34,448 bottles
#
#                                        reason_for_recall  \
# 0      Failed Impurities/Degradation Specifications: ...
# 1      Defective container; yellow colored spike from...
# 2      Defective container: potential for non-sealed ...
# 3              Label mix-up: Carton incorrectly labeled.
# 4                         Lack of Assurance of Sterility
# ...                                                  ...
# 16407                        Lack of Sterility Assurance
# 16408                                    cGMP deviations
# 16409  Lack of assurance of sterility: Bags have the ...
# 16410           Failed Content Uniformity Specifications
# 16411                                     Subpotent Drug
#
#       recall_initiation_date center_classification_date report_date  \
# 0                   20240807                   20240813    20240821
# 1                   20240718                   20240813    20240821
# 2                   20240702                   20240807    20240814
# 3                   20240718                   20240806    20240814
# 4                   20240802                   20240808    20240814
# ...                      ...                        ...         ...
# 16407               20231228                   20240104    20240110
# 16408               20230605                   20230626    20230705
# 16409               20221229                   20230105    20230111
# 16410               20231023                   20231220    20231227
# 16411               20240604                   20240618    20240626
#
#                                                code_info more_code_info  \
# 0                          Lot # AD12890, Exp 09/30/2024            NaN
# 1      Lot Number: 083J022, Expiration Date: Septembe...            NaN
# 2                  Lot #S300542, exp. date June 30, 2025            NaN
# 3                      Lot #: 31670346AA, Exp 12/31/2026            NaN
# 4             Lot #: 179338, Beyond use date: 08/14/2024            NaN
# ...                                                  ...            ...
# 16407  Part Number: 077-60621, Lot #: 23JK02010, Exp....            NaN
# 16408  Lot #2407, exp. date Feb-24; 2409A, exp. date ...            NaN
# 16409                      Lot: 5935283, Exp. 12/01/2023            NaN
# 16410  Lot# C00099, C00115 Exp. date: 07/31/2024; C00...            NaN
# 16411  Lot #: 100047634 Exp. Date 4/2025; 35449379A, ...            NaN
#
#       termination_date
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 16407              NaN
# 16408              NaN
# 16409              NaN
# 16410       20240710.0
# 16411              NaN
#
# [16412 rows x 26 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'fda_excluded_package'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
fda_excluded_package = pd.read_csv(path_csv_file, low_memory=False)
fda_excluded_package
# Out:
#                                              productid productndc  \
# 0       0002-0604_043d7847-900a-48f5-8f08-a88d14645706  0002-0604
# 1       0002-1210_e82b7e9c-6569-415d-9498-084612225c12  0002-1210
# 2       0002-1210_e82b7e9c-6569-415d-9498-084612225c12  0002-1210
# 3       0002-1214_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-1214
# 4       0002-1340_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-1340
# ...                                                ...        ...
# 323626  99207-741_c3a80599-ee1d-49a6-a244-38fdb7970c1e  99207-741
# 323627  99207-741_c3a80599-ee1d-49a6-a244-38fdb7970c1e  99207-741
# 323628  99207-744_c3a80599-ee1d-49a6-a244-38fdb7970c1e  99207-744
# 323629  99207-745_c3a80599-ee1d-49a6-a244-38fdb7970c1e  99207-745
# 323630  99207-745_c3a80599-ee1d-49a6-a244-38fdb7970c1e  99207-745
#
#        ndcpackagecode                                 packagedescription  \
# 0        0002-0604-40             40 CAPSULE in 1 BOTTLE (0002-0604-40)
# 1        0002-1210-30  1 VIAL, MULTI-DOSE in 1 CAN (0002-1210-30)  / ...
# 2        0002-1210-50  1 VIAL, MULTI-DOSE in 1 CAN (0002-1210-50)  / ...
# 3        0002-1214-04  4 VIAL, SINGLE-DOSE in 1 CARTON (0002-1214-04)...
# 4        0002-1340-04  4 VIAL, SINGLE-DOSE in 1 CARTON (0002-1340-04)...
# ...               ...                                                ...
# 323626   99207-741-06  1 TUBE in 1 CARTON (99207-741-06)  / 170.3 g i...
# 323627   99207-741-12                  340.2 g in 1 TUBE (99207-741-12)
# 323628   99207-744-04  1 TUBE in 1 CARTON (99207-744-04)  / 113.4 g i...
# 323629   99207-745-30  30 POUCH in 1 CARTON (99207-745-30)  / 3.7 g i...
# 323630   99207-745-60  60 POUCH in 1 CARTON (99207-745-60)  / 3.7 g i...
#
#         startmarketingdate  endmarketingdate ndc_exclude_flag sample_package
# 0               19560901.0        20100208.0                D              N
# 1               20200528.0        20221024.0                D              N
# 2               20200528.0        20221024.0                D              N
# 3               20240808.0        20240808.0                D              N
# 4               20240808.0        20240808.0                D              N
# ...                    ...               ...              ...            ...
# 323626          20000601.0        20110302.0                D              N
# 323627          20000601.0        20110302.0                D              N
# 323628          20000601.0        20110302.0                D              N
# 323629          20050901.0        20110302.0                D              N
# 323630          20050901.0        20110302.0                D              N
#
# [323631 rows x 8 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'fda_excluded_product'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
fda_excluded_product = pd.read_csv(path_csv_file, low_memory=False)
fda_excluded_product
# Out:
#                                              productid productndc  \
# 0       0002-0604_043d7847-900a-48f5-8f08-a88d14645706  0002-0604
# 1       0002-1210_e82b7e9c-6569-415d-9498-084612225c12  0002-1210
# 2       0002-1407_3d42507b-6c2c-42ec-a8a2-a6e6a155e8c6  0002-1407
# 3       0002-1485_5879f620-a79a-468a-9eb5-da9b2bf6d584  0002-1485
# 4       0002-1975_39ce72df-8f3b-4db6-b450-d75351a05446  0002-1975
# ...                                                ...        ...
# 171005  99207-514_53eb3a5d-0c55-41f6-a5ac-d2a662f9b104  99207-514
# 171006  99207-517_913eea79-7537-464b-aacb-9fe86dc0e32b  99207-517
# 171007  99207-741_c3a80599-ee1d-49a6-a244-38fdb7970c1e  99207-741
# 171008  99207-744_c3a80599-ee1d-49a6-a244-38fdb7970c1e  99207-744
# 171009  99207-745_c3a80599-ee1d-49a6-a244-38fdb7970c1e  99207-745
#
#         producttypename      proprietaryname proprietarynamesuffix  \
# 0                   NaN            Seromycin                   NaN
# 1                   NaN               TAUVID                   NaN
# 2                   NaN  Quinidine Gluconate                   NaN
# 3                   NaN     Capastat sulfate                   NaN
# 4                   NaN               AXIRON                   NaN
# ...                 ...                  ...                   ...
# 171005              NaN                Lidex                   NaN
# 171006              NaN                Lidex                   NaN
# 171007              NaN     Plexion Cleanser                   NaN
# 171008              NaN          Plexion SCT                   NaN
# 171009              NaN    Plexion Cleansing                   NaN
#
#         nonproprietaryname  dosageformname  routename  startmarketingdate  \
# 0                      NaN             NaN        NaN          19560901.0
# 1                      NaN             NaN        NaN          20200528.0
# 2                      NaN             NaN        NaN          19500712.0
# 3                      NaN             NaN        NaN          19711001.0
# 4                      NaN             NaN        NaN          20101123.0
# ...                    ...             ...        ...                 ...
# 171005                 NaN             NaN        NaN          19970401.0
# 171006                 NaN             NaN        NaN          19990401.0
# 171007                 NaN             NaN        NaN          20000601.0
# 171008                 NaN             NaN        NaN          20000601.0
# 171009                 NaN             NaN        NaN          20050901.0
#
#         endmarketingdate  marketingcategoryname applicationnumber  \
# 0             20100208.0                    NDA         NDA060593
# 1             20240219.0                    NDA         NDA212123
# 2             20191009.0                    NDA         NDA007529
# 3             20110630.0                    NDA         NDA050095
# 4             20190131.0                    NDA         NDA022504
# ...                  ...                    ...               ...
# 171005        20070606.0                    NDA         NDA016909
# 171006        20070606.0                    NDA         NDA018849
# 171007        20110302.0  UNAPPROVED DRUG OTHER               NaN
# 171008        20110302.0  UNAPPROVED DRUG OTHER               NaN
# 171009        20110302.0  UNAPPROVED DRUG OTHER               NaN
#
#                          labelername  substancename  \
# 0              Eli Lilly and Company            NaN
# 1              Eli Lilly and Company            NaN
# 2              Eli Lilly and Company            NaN
# 3              Eli Lilly and Company            NaN
# 4              Eli Lilly and Company            NaN
# ...                              ...            ...
# 171005   Medicis Pharmaceutical Corp            NaN
# 171006   Medicis Pharmaceutical Corp            NaN
# 171007  Medicis Pharmaceutical Corp.            NaN
# 171008  Medicis Pharmaceutical Corp.            NaN
# 171009  Medicis Pharmaceutical Corp.            NaN
#
#         active_numerator_strength  active_ingred_unit  pharm_classes  \
# 0                             NaN                 NaN            NaN
# 1                             NaN                 NaN            NaN
# 2                             NaN                 NaN            NaN
# 3                             NaN                 NaN            NaN
# 4                             NaN                 NaN            NaN
# ...                           ...                 ...            ...
# 171005                        NaN                 NaN            NaN
# 171006                        NaN                 NaN            NaN
# 171007                        NaN                 NaN            NaN
# 171008                        NaN                 NaN            NaN
# 171009                        NaN                 NaN            NaN
#
#         deaschedule ndc_exclude_flag  listing_record_certified_through
# 0               NaN                D                        20100208.0
# 1               NaN                D                        20240219.0
# 2               NaN                D                        20191009.0
# 3               NaN                D                        20110630.0
# 4               NaN                D                        20190131.0
# ...             ...              ...                               ...
# 171005          NaN                D                        20070606.0
# 171006          NaN                D                        20070606.0
# 171007          NaN                D                        20110302.0
# 171008          NaN                D                        20110302.0
# 171009          NaN                D                        20110302.0
#
# [171010 rows x 20 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'fda_ndc_package'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
fda_ndc_package = pd.read_csv(path_csv_file, low_memory=False)
fda_ndc_package
# Out:
#                                              productid productndc  \
# 0       0002-0152_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0152
# 1       0002-0152_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0152
# 2       0002-0213_458ef2aa-cd5f-48bc-8829-82420cfed33b  0002-0213
# 3       0002-0243_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0243
# 4       0002-0243_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0243
# ...                                                ...        ...
# 218379  99528-606_f1e9f234-cca3-876f-e053-2995a90a5d40  99528-606
# 218380  99528-606_f1e9f234-cca3-876f-e053-2995a90a5d40  99528-606
# 218381  99528-606_f1e9f234-cca3-876f-e053-2995a90a5d40  99528-606
# 218382  99528-606_f1e9f234-cca3-876f-e053-2995a90a5d40  99528-606
# 218383  99528-606_f1e9f234-cca3-876f-e053-2995a90a5d40  99528-606
#
#        ndcpackagecode                                 packagedescription  \
# 0        0002-0152-01  1 VIAL, SINGLE-DOSE in 1 CARTON (0002-0152-01)...
# 1        0002-0152-04  4 VIAL, SINGLE-DOSE in 1 CARTON (0002-0152-04)...
# 2        0002-0213-01  1 VIAL, MULTI-DOSE in 1 CARTON (0002-0213-01) ...
# 3        0002-0243-01  1 VIAL, SINGLE-DOSE in 1 CARTON (0002-0243-01)...
# 4        0002-0243-04  4 VIAL, SINGLE-DOSE in 1 CARTON (0002-0243-04)...
# ...               ...                                                ...
# 218379   99528-606-06                  6 TABLET in 1 BAG (99528-606-06)
# 218380   99528-606-12                 12 TABLET in 1 BAG (99528-606-12)
# 218381   99528-606-25             250 TABLET in 1 BOTTLE (99528-606-25)
# 218382   99528-606-45              45 TABLET in 1 BOTTLE (99528-606-45)
# 218383   99528-606-90              90 TABLET in 1 BOTTLE (99528-606-90)
#
#         startmarketingdate  endmarketingdate ndc_exclude_flag sample_package
# 0                 20240328               NaN                N              N
# 1                 20240808               NaN                N              N
# 2                 20230620               NaN                N              N
# 3                 20240328               NaN                N              N
# 4                 20240808               NaN                N              N
# ...                    ...               ...              ...            ...
# 218379            19860612               NaN                N              N
# 218380            20170601               NaN                N              Y
# 218381            19860612               NaN                N              N
# 218382            20191101               NaN                N              N
# 218383            19860612               NaN                N              N
#
# [218384 rows x 8 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'fda_ndc_product'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
fda_ndc_product = pd.read_csv(path_csv_file, low_memory=False)
fda_ndc_product
# Out:
#                                              productid productndc  \
# 0       0002-0152_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0152
# 1       0002-0213_458ef2aa-cd5f-48bc-8829-82420cfed33b  0002-0213
# 2       0002-0243_feb81a67-85f4-4f8f-93bf-f893037cbd00  0002-0243
# 3       0002-1152_333d2c1f-1a90-4b73-bf8a-85c7a9a0d21b  0002-1152
# 4       0002-1200_c2f899b5-287a-4002-ae37-f69418174eb4  0002-1200
# ...                                                ...        ...
# 115045  99207-300_4b7e1338-0ec2-4a3f-acbd-8605c74d5d40  99207-300
# 115046  99207-466_bcf77466-9c0c-4ebf-a1ee-b41456b1e662  99207-466
# 115047  99207-525_1264ffef-0305-1699-e063-6394a90a2140  99207-525
# 115048  99207-850_e52ec481-1114-4f09-9be0-311e5eb52fa1  99207-850
# 115049  99528-606_f1e9f234-cca3-876f-e053-2995a90a5d40  99528-606
#
#                 producttypename proprietaryname proprietarynamesuffix  \
# 0       HUMAN PRESCRIPTION DRUG        Zepbound                   NaN
# 1                HUMAN OTC DRUG         Humulin                     R
# 2       HUMAN PRESCRIPTION DRUG        Zepbound                   NaN
# 3       HUMAN PRESCRIPTION DRUG        MOUNJARO                   NaN
# 4       HUMAN PRESCRIPTION DRUG          Amyvid                   NaN
# ...                         ...             ...                   ...
# 115045  HUMAN PRESCRIPTION DRUG           ZIANA                   NaN
# 115046  HUMAN PRESCRIPTION DRUG         Solodyn                   NaN
# 115047  HUMAN PRESCRIPTION DRUG           Vanos                   NaN
# 115048  HUMAN PRESCRIPTION DRUG            Luzu                   NaN
# 115049           HUMAN OTC DRUG         Valerin                   NaN
#
#                                     nonproprietaryname  \
# 0                                          tirzepatide
# 1                                        Insulin human
# 2                                          tirzepatide
# 3                                          tirzepatide
# 4                                     Florbetapir F 18
# ...                                                ...
# 115045             clindamycin phosphate and tretinoin
# 115046                       minocycline hydrochloride
# 115047                                    fluocinonide
# 115048                                    LULICONAZOLE
# 115049  Valerian Root, Passiflora, Magnesium Carbonate
#
#                                dosageformname     routename  \
# 0                         INJECTION, SOLUTION  SUBCUTANEOUS
# 1                         INJECTION, SOLUTION    PARENTERAL
# 2                         INJECTION, SOLUTION  SUBCUTANEOUS
# 3                         INJECTION, SOLUTION  SUBCUTANEOUS
# 4                         INJECTION, SOLUTION   INTRAVENOUS
# ...                                       ...           ...
# 115045                                    GEL       TOPICAL
# 115046  TABLET, FILM COATED, EXTENDED RELEASE          ORAL
# 115047                                  CREAM       TOPICAL
# 115048                                  CREAM       TOPICAL
# 115049                                 TABLET          ORAL
#
#         startmarketingdate  endmarketingdate   marketingcategoryname  \
# 0                 20231108               NaN                     NDA
# 1                 19830627               NaN                     BLA
# 2                 20231108               NaN                     NDA
# 3                 20230728               NaN                     NDA
# 4                 20120601               NaN                     NDA
# ...                    ...               ...                     ...
# 115045            20061201               NaN                     NDA
# 115046            20100927        20241031.0                     NDA
# 115047            20060313               NaN                     NDA
# 115048            20131114               NaN                     NDA
# 115049            19860612               NaN  UNAPPROVED HOMEOPATHIC
#
#        applicationnumber            labelername  \
# 0              NDA217806  Eli Lilly and Company
# 1              BLA018780  Eli Lilly and Company
# 2              NDA217806  Eli Lilly and Company
# 3              NDA215866  Eli Lilly and Company
# 4              NDA202008  Eli Lilly and Company
# ...                  ...                    ...
# 115045         NDA050802  Bausch Health US, LLC
# 115046         NDA050808   Bausch Health US LLC
# 115047         NDA021758  Bausch Health US, LLC
# 115048         NDA204153  Bausch Health US, LLC
# 115049               NaN    Wonder Laboratories
#
#                                             substancename  \
# 0                                             TIRZEPATIDE
# 1                                           INSULIN HUMAN
# 2                                             TIRZEPATIDE
# 3                                             TIRZEPATIDE
# 4                                        FLORBETAPIR F-18
# ...                                                   ...
# 115045                   CLINDAMYCIN PHOSPHATE; TRETINOIN
# 115046                          MINOCYCLINE HYDROCHLORIDE
# 115047                                       FLUOCINONIDE
# 115048                                       LULICONAZOLE
# 115049  MAGNESIUM CARBONATE; PASSIFLORA INCARNATA FLOW...
#
#        active_numerator_strength            active_ingred_unit  \
# 0                            2.5                       mg/.5mL
# 1                            100                       [iU]/mL
# 2                              5                       mg/.5mL
# 3                            2.5                       mg/.5mL
# 4                             51                        mCi/mL
# ...                          ...                           ...
# 115045                   12; .25                    mg/g; mg/g
# 115046                        80                          mg/1
# 115047                         1                          mg/g
# 115048                        10                          mg/g
# 115049                   1; 3; 6  [hp_X]/1; [hp_X]/1; [hp_X]/1
#
#                                             pharm_classes deaschedule  \
# 0       G-Protein-linked Receptor Interactions [MoA], ...         NaN
# 1                             Insulin [CS], Insulin [EPC]         NaN
# 2       G-Protein-linked Receptor Interactions [MoA], ...         NaN
# 3       G-Protein-linked Receptor Interactions [MoA], ...         NaN
# 4       Positron Emitting Activity [MoA], Radioactive ...         NaN
# ...                                                   ...         ...
# 115045  Decreased Sebaceous Gland Activity [PE], Linco...         NaN
# 115046  Decreased Prothrombin Activity [PE], Tetracycl...         NaN
# 115047  Corticosteroid Hormone Receptor Agonists [MoA]...         NaN
# 115048  Azole Antifungal [EPC], Azoles [CS], Cytochrom...         NaN
# 115049                                                NaN         NaN
#
#        ndc_exclude_flag  listing_record_certified_through
# 0                     N                        20251231.0
# 1                     N                        20241231.0
# 2                     N                        20251231.0
# 3                     N                        20251231.0
# 4                     N                        20241231.0
# ...                 ...                               ...
# 115045                N                        20241231.0
# 115046                N                               NaN
# 115047                N                        20251231.0
# 115048                N                        20241231.0
# 115049                N                        20241231.0
#
# [115050 rows x 20 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'fda_unfinished_product'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
fda_unfinished_product = pd.read_csv(path_csv_file, low_memory=False)
fda_unfinished_product
# Out:
#                                              productid  productndc  \
# 0       0002-0013_15810e26-b479-41b8-9d13-9dc503a71a2a   0002-0013
# 1       0002-0095_15810e26-b479-41b8-9d13-9dc503a71a2a   0002-0095
# 2       0002-0096_15810e26-b479-41b8-9d13-9dc503a71a2a   0002-0096
# 3       0002-0113_55aa4078-e1e8-4338-b2b5-a9298b3c16e2   0002-0113
# 4       0002-0119_55aa4078-e1e8-4338-b2b5-a9298b3c16e2   0002-0119
# ...                                                ...         ...
# 20034   90027-028_030de22c-fc5e-e060-e063-6294a90ad320   90027-028
# 20035   90027-029_05621521-2cc3-9b8a-e063-6394a90a2cd2   90027-029
# 20036   90027-030_05621f37-04b1-dba5-e063-6294a90a4a28   90027-030
# 20037   90027-031_06288ce6-eb64-aca7-e063-6394a90aa71a   90027-031
# 20038  90112-3000_3467222f-bda4-4d8c-8d10-90b0a6b378c9  90112-3000
#
#                    producttypename nonproprietaryname         dosageformname  \
# 0      DRUG FOR FURTHER PROCESSING      Insulin human    INJECTION, SOLUTION
# 1      DRUG FOR FURTHER PROCESSING      Insulin human    INJECTION, SOLUTION
# 2      DRUG FOR FURTHER PROCESSING      Insulin human    INJECTION, SOLUTION
# 3      DRUG FOR FURTHER PROCESSING      Insulin human  INJECTION, SUSPENSION
# 4      DRUG FOR FURTHER PROCESSING      Insulin human  INJECTION, SUSPENSION
# ...                            ...                ...                    ...
# 20034              BULK INGREDIENT    CHOLECALCIFEROL                 POWDER
# 20035              BULK INGREDIENT        Semaglutide                 POWDER
# 20036              BULK INGREDIENT        Tirzepatide                 POWDER
# 20037              BULK INGREDIENT        Latanoprost                 POWDER
# 20038  DRUG FOR FURTHER PROCESSING        anifrolumab    INJECTION, SOLUTION
#
#        startmarketingdate  endmarketingdate  \
# 0                19830627               NaN
# 1                20151229               NaN
# 2                19940331               NaN
# 3                19830627               NaN
# 4                20131107               NaN
# ...                   ...               ...
# 20034            20230816               NaN
# 20035            20230915               NaN
# 20036            20230915               NaN
# 20037            20230925               NaN
# 20038            20210730               NaN
#
#                                    marketingcategoryname  \
# 0                            DRUG FOR FURTHER PROCESSING
# 1                            DRUG FOR FURTHER PROCESSING
# 2                            DRUG FOR FURTHER PROCESSING
# 3                            DRUG FOR FURTHER PROCESSING
# 4                            DRUG FOR FURTHER PROCESSING
# ...                                                  ...
# 20034  BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUN...
# 20035  BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUN...
# 20036  BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUN...
# 20037  BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUN...
# 20038                        DRUG FOR FURTHER PROCESSING
#
#                        labelername    substancename active_numerator_strength  \
# 0            Eli Lilly and Company    INSULIN HUMAN                       100
# 1            Eli Lilly and Company    INSULIN HUMAN                       500
# 2            Eli Lilly and Company    INSULIN HUMAN                       500
# 3            Eli Lilly and Company    INSULIN HUMAN                       100
# 4            Eli Lilly and Company    INSULIN HUMAN                       100
# ...                            ...              ...                       ...
# 20034  QINGDAO TIDA BIOTEK CO.,LTD  CHOLECALCIFEROL                         1
# 20035  QINGDAO TIDA BIOTEK CO.,LTD      SEMAGLUTIDE                         1
# 20036  QINGDAO TIDA BIOTEK CO.,LTD      TIRZEPATIDE                         1
# 20037  QINGDAO TIDA BIOTEK CO.,LTD      LATANOPROST                         1
# 20038    AstraZeneca Nijmegen B.V.      ANIFROLUMAB                       300
#
#       active_ingred_unit deaschedule  listing_record_certified_through
# 0                [iU]/mL         NaN                        20241231.0
# 1                [iU]/mL         NaN                        20241231.0
# 2                [iU]/mL         NaN                        20241231.0
# 3                [iU]/mL         NaN                        20241231.0
# 4                [iU]/mL         NaN                        20241231.0
# ...                  ...         ...                               ...
# 20034              kg/kg         NaN                        20241231.0
# 20035                g/g         NaN                        20241231.0
# 20036                g/g         NaN                        20241231.0
# 20037                g/g         NaN                        20241231.0
# 20038             mg/2mL         NaN                        20241231.0
#
# [20039 rows x 14 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'fda_unfinished_product'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
fda_unfinished_product = pd.read_csv(path_csv_file, low_memory=False)
fda_unfinished_product
# Out:
#                                              productid  productndc  \
# 0       0002-0013_15810e26-b479-41b8-9d13-9dc503a71a2a   0002-0013
# 1       0002-0095_15810e26-b479-41b8-9d13-9dc503a71a2a   0002-0095
# 2       0002-0096_15810e26-b479-41b8-9d13-9dc503a71a2a   0002-0096
# 3       0002-0113_55aa4078-e1e8-4338-b2b5-a9298b3c16e2   0002-0113
# 4       0002-0119_55aa4078-e1e8-4338-b2b5-a9298b3c16e2   0002-0119
# ...                                                ...         ...
# 20034   90027-028_030de22c-fc5e-e060-e063-6294a90ad320   90027-028
# 20035   90027-029_05621521-2cc3-9b8a-e063-6394a90a2cd2   90027-029
# 20036   90027-030_05621f37-04b1-dba5-e063-6294a90a4a28   90027-030
# 20037   90027-031_06288ce6-eb64-aca7-e063-6394a90aa71a   90027-031
# 20038  90112-3000_3467222f-bda4-4d8c-8d10-90b0a6b378c9  90112-3000
#
#                    producttypename nonproprietaryname         dosageformname  \
# 0      DRUG FOR FURTHER PROCESSING      Insulin human    INJECTION, SOLUTION
# 1      DRUG FOR FURTHER PROCESSING      Insulin human    INJECTION, SOLUTION
# 2      DRUG FOR FURTHER PROCESSING      Insulin human    INJECTION, SOLUTION
# 3      DRUG FOR FURTHER PROCESSING      Insulin human  INJECTION, SUSPENSION
# 4      DRUG FOR FURTHER PROCESSING      Insulin human  INJECTION, SUSPENSION
# ...                            ...                ...                    ...
# 20034              BULK INGREDIENT    CHOLECALCIFEROL                 POWDER
# 20035              BULK INGREDIENT        Semaglutide                 POWDER
# 20036              BULK INGREDIENT        Tirzepatide                 POWDER
# 20037              BULK INGREDIENT        Latanoprost                 POWDER
# 20038  DRUG FOR FURTHER PROCESSING        anifrolumab    INJECTION, SOLUTION
#
#        startmarketingdate  endmarketingdate  \
# 0                19830627               NaN
# 1                20151229               NaN
# 2                19940331               NaN
# 3                19830627               NaN
# 4                20131107               NaN
# ...                   ...               ...
# 20034            20230816               NaN
# 20035            20230915               NaN
# 20036            20230915               NaN
# 20037            20230925               NaN
# 20038            20210730               NaN
#
#                                    marketingcategoryname  \
# 0                            DRUG FOR FURTHER PROCESSING
# 1                            DRUG FOR FURTHER PROCESSING
# 2                            DRUG FOR FURTHER PROCESSING
# 3                            DRUG FOR FURTHER PROCESSING
# 4                            DRUG FOR FURTHER PROCESSING
# ...                                                  ...
# 20034  BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUN...
# 20035  BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUN...
# 20036  BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUN...
# 20037  BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUN...
# 20038                        DRUG FOR FURTHER PROCESSING
#
#                        labelername    substancename active_numerator_strength  \
# 0            Eli Lilly and Company    INSULIN HUMAN                       100
# 1            Eli Lilly and Company    INSULIN HUMAN                       500
# 2            Eli Lilly and Company    INSULIN HUMAN                       500
# 3            Eli Lilly and Company    INSULIN HUMAN                       100
# 4            Eli Lilly and Company    INSULIN HUMAN                       100
# ...                            ...              ...                       ...
# 20034  QINGDAO TIDA BIOTEK CO.,LTD  CHOLECALCIFEROL                         1
# 20035  QINGDAO TIDA BIOTEK CO.,LTD      SEMAGLUTIDE                         1
# 20036  QINGDAO TIDA BIOTEK CO.,LTD      TIRZEPATIDE                         1
# 20037  QINGDAO TIDA BIOTEK CO.,LTD      LATANOPROST                         1
# 20038    AstraZeneca Nijmegen B.V.      ANIFROLUMAB                       300
#
#       active_ingred_unit deaschedule  listing_record_certified_through
# 0                [iU]/mL         NaN                        20241231.0
# 1                [iU]/mL         NaN                        20241231.0
# 2                [iU]/mL         NaN                        20241231.0
# 3                [iU]/mL         NaN                        20241231.0
# 4                [iU]/mL         NaN                        20241231.0
# ...                  ...         ...                               ...
# 20034              kg/kg         NaN                        20241231.0
# 20035                g/g         NaN                        20241231.0
# 20036                g/g         NaN                        20241231.0
# 20037                g/g         NaN                        20241231.0
# 20038             mg/2mL         NaN                        20241231.0
#
# [20039 rows x 14 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'fda_unii'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
fda_unii = pd.read_csv(path_csv_file, low_memory=False)
fda_unii
# Out:
#               unii                                       display_name  \
# 0       0001H6R5H1                                  CEROUS SALICYLATE
# 1       000360VJE1                    DI(DEHYDROABIETYL)AMINE ACETATE
# 2       0005633KTU                 SYMPHYOTRICHUM OBLONGIFOLIUM WHOLE
# 3       000705ZASD                                       ADECATUMUMAB
# 4       00072J7XWS                                          GERMANIUM
# ...            ...                                                ...
# 154556  ZZW95F4360                    DIPOTASSIUM GLUCOSE-6-PHOSPHATE
# 154557  ZZW9CP4P2Z  SUNBURST ORANGE BETTA TRANSGENIC WHOLE (OBS201...
# 154558  ZZY773V99Q                             ALOYSIA WRIGHTII WHOLE
# 154559  ZZY9N8B3WA  HEMAGGLUTININ PREPROTEIN (INFLUENZA A VIRUS (A...
# 154560  ZZZ3BU4OA7                                      SULFASYMAZINE
#
#                  rn         ec     ncit      rxcui     pubchem  \
# 0          526-17-0        NaN      NaN        NaN  76966289.0
# 1        53404-27-6        NaN      NaN        NaN  76969106.0
# 2               NaN        NaN      NaN        NaN         NaN
# 3       503605-66-1        NaN   C82358        NaN         NaN
# 4         7440-56-4  231-164-3   C95170     4784.0   6326954.0
# ...             ...        ...      ...        ...         ...
# 154556    5996-17-8  227-837-6      NaN  1541245.0    111126.0
# 154557          NaN        NaN      NaN        NaN         NaN
# 154558          NaN        NaN      NaN        NaN         NaN
# 154559          NaN        NaN      NaN        NaN         NaN
# 154560    1984-94-7        NaN  C152458        NaN     16132.0
#
#            epa_comptox catalogue_of_life      itis  ...            mpns  \
# 0       DTXSID90200572               NaN       NaN  ...             NaN
# 1       DTXSID50109138               NaN       NaN  ...             NaN
# 2                  NaN             53Q8M  522228.0  ...  WCSCMP-3103632
# 3                  NaN               NaN       NaN  ...             NaN
# 4        DTXSID8052483               NaN       NaN  ...             NaN
# ...                ...               ...       ...  ...             ...
# 154556  DTXSID60975386               NaN       NaN  ...             NaN
# 154557             NaN               NaN       NaN  ...             NaN
# 154558             NaN              C5TK   32134.0  ...        WCS-6961
# 154559             NaN               NaN       NaN  ...             NaN
# 154560  DTXSID80173584               NaN       NaN  ...             NaN
#
#         inn_id usan_id              mf                     inchikey  \
# 0          NaN     NaN      3C7H5O3.Ce  RBJPAJHTYHKKTB-UHFFFAOYSA-K
# 1          NaN     NaN  C40H59N.C2H4O2  SETIUTJHVNMKFM-TUICDNFPSA-N
# 2          NaN     NaN             NaN                          NaN
# 3       8449.0     NaN             NaN                          NaN
# 4          NaN     NaN              Ge  GNPVGFCGXDBREM-UHFFFAOYSA-N
# ...        ...     ...             ...                          ...
# 154556     NaN     NaN     C6H11O9P.2K  BWHWCIODKVRLNE-FAOVPRGRSA-L
# 154557     NaN     NaN             NaN                          NaN
# 154558     NaN     NaN             NaN                          NaN
# 154559     NaN     NaN             NaN                          NaN
# 154560  1097.0     NaN     C13H17N5O2S  ZQMQGBHQZZQTJE-UHFFFAOYSA-N
#
#                                                    smiles  \
# 0       [Ce+3].c1(ccccc1O)C([O-])=O.c1(ccccc1O)C([O-])...
# 1       C[C@@]12c3ccc(C(C)C)cc3CC[C@]1([C@](CCC2)(C)CN...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                    [Ge]
# ...                                                   ...
# 154556  [K+].O(P([O-])([O-])=O)C[C@@H](O)[C@@H](O)[C@H...
# 154557                                                NaN
# 154558                                                NaN
# 154559                                                NaN
# 154560            S(Nc1nc(CC)nc(n1)CC)(c2ccc(cc2)N)(=O)=O
#
#              ingredient_type       substance_type  \
# 0       INGREDIENT SUBSTANCE             chemical
# 1       INGREDIENT SUBSTANCE             chemical
# 2       INGREDIENT SUBSTANCE  structurallyDiverse
# 3       INGREDIENT SUBSTANCE              protein
# 4       INGREDIENT SUBSTANCE             chemical
# ...                      ...                  ...
# 154556  INGREDIENT SUBSTANCE             chemical
# 154557  INGREDIENT SUBSTANCE  structurallyDiverse
# 154558  INGREDIENT SUBSTANCE  structurallyDiverse
# 154559  INGREDIENT SUBSTANCE              protein
# 154560  INGREDIENT SUBSTANCE             chemical
#
#                                         uuid    dailymed
# 0       15f0bc75-ff62-4ca4-a8a2-9132a0c211ce         NaN
# 1       4d3e2f1f-80f6-4f92-80cf-8daa37480cea         NaN
# 2       c3c04d85-4363-4b75-9c6e-1d752b00056b  0005633KTU
# 3       4326d0e7-d9a4-4fd7-8e19-0d753a038922         NaN
# 4       13c631e3-998c-47ac-b161-7be7a0e5b98b  00072J7XWS
# ...                                      ...         ...
# 154556  0e1ff85a-b1b8-4e7c-b790-358b2eb648f0  ZZW95F4360
# 154557  6a21f8b0-df62-be21-3331-4c84fc43edb8  ZZW9CP4P2Z
# 154558  d224e0ca-853f-4d06-86be-75e9e2ac8f1c         NaN
# 154559  2856eab4-a82d-4304-85a9-3181f2cf19f0         NaN
# 154560  782c153b-55b6-4007-a7f4-0f4f9c17d15f         NaN
#
# [154561 rows x 23 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'nadac'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
nadac = pd.read_csv(path_csv_file, low_memory=False)
nadac
# Out:
#                        ndc_description          ndc  nadac_per_unit  \
# 0       12HR NASAL DECONGEST ER 120 MG  24385005452         0.26838
# 1       12HR NASAL DECONGEST ER 120 MG  70000047501         0.26838
# 2       24H NASAL ALLERGY 55 MCG SPRAY  46122038576         0.76188
# 3       24HR ALLERGY(LEVOCETIRZN) 5 MG  70000036201         0.20773
# 4       24HR ALLERGY(LEVOCETIRZN) 5 MG  70000036202         0.20773
# ...                                ...          ...             ...
# 990556            ZYPREXA 20 MG TABLET      2442030        45.36752
# 990557             ZYPREXA 5 MG TABLET      2411530        15.23249
# 990558           ZYPREXA 7.5 MG TABLET      2411630        18.26917
# 990559       ZYPREXA ZYDIS 5 MG TABLET      2445301        16.11767
# 990560       ZYPREXA ZYDIS 5 MG TABLET      2445385        16.11767
#
#        effective_date pricing_unit pharmacy_type_indicator otc  \
# 0          2023-12-20           EA                     C/I   Y
# 1          2023-12-20           EA                     C/I   Y
# 2          2023-12-20           ML                     C/I   Y
# 3          2023-12-20           EA                     C/I   Y
# 4          2023-12-20           EA                     C/I   Y
# ...               ...          ...                     ...  ..
# 990556     2024-08-21           EA                     C/I   N
# 990557     2024-08-21           EA                     C/I   N
# 990558     2024-08-21           EA                     C/I   N
# 990559     2024-08-21           EA                     C/I   N
# 990560     2024-08-21           EA                     C/I   N
#
#        explanation_code classifiation_for_rate_setting  \
# 0                     1                              G
# 1                     1                              G
# 2                  1, 5                              G
# 3                     1                              G
# 4                     1                              G
# ...                 ...                            ...
# 990556                1                              B
# 990557                1                              B
# 990558                1                              B
# 990559                1                              B
# 990560                1                              B
#
#         corresponding_generic_drug_nadac_per_unit  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 990556                                    0.17195
# 990557                                    0.08604
# 990558                                    0.10471
# 990559                                    0.30098
# 990560                                    0.30098
#
#        corresponding_generic_drug_effective_date  as_of_date
# 0                                            NaN  2024-01-03
# 1                                            NaN  2024-01-03
# 2                                            NaN  2024-01-03
# 3                                            NaN  2024-01-03
# 4                                            NaN  2024-01-03
# ...                                          ...         ...
# 990556                                2024-08-21  2024-08-28
# 990557                                2024-08-21  2024-08-28
# 990558                                2024-08-21  2024-08-28
# 990559                                2024-08-21  2024-08-28
# 990560                                2024-08-21  2024-08-28
#
# [990561 rows x 12 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'orange_book_exlusivity'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
orange_book_exlusivity = pd.read_csv(path_csv_file, low_memory=False)
orange_book_exlusivity
# Out:
#      appl_type  appl_no  product_no exclusivity_code exclusivity_date
# 0            N    17031           1              RTO     Jul 13, 2026
# 1            N    18680           1            D-193     Jun 28, 2027
# 2            N    20263           9               NS     Apr 14, 2026
# 3            N    20825           1            M-232     Jan 28, 2025
# 4            N    20825           2            M-232     Jan 28, 2025
# ...        ...      ...         ...              ...              ...
# 2226         N   215153           1             GAIN      May 3, 2032
# 2227         N   215888           1             GAIN     Apr 26, 2032
# 2228         N   218275           1             GAIN      Apr 3, 2034
# 2229         N   213004           1             GAIN      Nov 1, 2027
# 2230         N   217417           1             GAIN     Mar 22, 2033
#
# [2231 rows x 5 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'orange_book_patent'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
orange_book_patent = pd.read_csv(path_csv_file, low_memory=False)
orange_book_patent
# Out:
#       appl_type  appl_no  product_no     patent_no patent_expire_date_text  \
# 0             N    20610           1       7625884            Aug 24, 2026
# 1             N    18613           1       7560445             Feb 1, 2027
# 2             N    19734           2       8455524            Apr 18, 2027
# 3             N    19734           5       8455524            Apr 18, 2027
# 4             N    20832           7       7422388            Apr 25, 2027
# ...         ...      ...         ...           ...                     ...
# 19249         N   212614           4  10258637*PED             Oct 3, 2034
# 19250         N   212614           1  11090323*PED             Oct 3, 2034
# 19251         N   212614           2  11090323*PED             Oct 3, 2034
# 19252         N   212614           3  11090323*PED             Oct 3, 2034
# 19253         N   212614           4  11090323*PED             Oct 3, 2034
#
#       drug_substance_flag drug_product_flag patent_use_code delist_flag  \
# 0                     NaN               NaN           U-141         NaN
# 1                       Y                 Y           U-986         NaN
# 2                     NaN               NaN          U-1029         NaN
# 3                     NaN               NaN          U-1029         NaN
# 4                     NaN                 Y          U-1397         NaN
# ...                   ...               ...             ...         ...
# 19249                 NaN               NaN             NaN         NaN
# 19250                 NaN               NaN             NaN         NaN
# 19251                 NaN               NaN             NaN         NaN
# 19252                 NaN               NaN             NaN         NaN
# 19253                 NaN               NaN             NaN         NaN
#
#       submission_date
# 0                 NaN
# 1                 NaN
# 2        Jun 27, 2013
# 3                 NaN
# 4                 NaN
# ...               ...
# 19249             NaN
# 19250             NaN
# 19251             NaN
# 19252             NaN
# 19253             NaN
#
# [19254 rows x 10 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'orange_book_products'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
orange_book_products = pd.read_csv(path_csv_file, low_memory=False)
orange_book_products
# Out:
#                       ingredient                     df_route  \
# 0                     BUDESONIDE         AEROSOL, FOAM;RECTAL
# 1                     BUDESONIDE         AEROSOL, FOAM;RECTAL
# 2      MINOCYCLINE HYDROCHLORIDE        AEROSOL, FOAM;TOPICAL
# 3                   AZELAIC ACID        AEROSOL, FOAM;TOPICAL
# 4         BETAMETHASONE VALERATE        AEROSOL, FOAM;TOPICAL
# ...                          ...                          ...
# 45370           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 45371           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 45372           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 45373           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 45374           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
#
#                    trade_name        applicant       strength appl_type  \
# 0                  BUDESONIDE   PADAGIS ISRAEL  2MG/ACTUATION         A
# 1                      UCERIS            SALIX  2MG/ACTUATION         N
# 2                      AMZEEQ          JOURNEY     EQ 4% BASE         N
# 3                AZELAIC ACID  TEVA PHARMS USA            15%         A
# 4      BETAMETHASONE VALERATE      NOVAST LABS          0.12%         A
# ...                       ...              ...            ...       ...
# 45370        FENTANYL CITRATE       SPECGX LLC  EQ 0.4MG BASE         A
# 45371        FENTANYL CITRATE       SPECGX LLC  EQ 0.6MG BASE         A
# 45372        FENTANYL CITRATE       SPECGX LLC  EQ 0.8MG BASE         A
# 45373        FENTANYL CITRATE       SPECGX LLC  EQ 1.2MG BASE         A
# 45374        FENTANYL CITRATE       SPECGX LLC  EQ 1.6MG BASE         A
#
#        appl_no  product_no te_code approval_date  rld   rs   type  \
# 0       215328           1      AB  Apr 12, 2023   No  Yes     RX
# 1       205613           1      AB   Oct 7, 2014  Yes   No     RX
# 2       212379           1     NaN  Oct 18, 2019  Yes  Yes     RX
# 3       210928           1     NaN   Oct 7, 2020   No   No  DISCN
# 4       207144           1     NaN  May 24, 2017   No   No  DISCN
# ...        ...         ...     ...           ...  ...  ...    ...
# 45370    78907           2     NaN  Oct 30, 2009   No   No  DISCN
# 45371    78907           3     NaN  Oct 30, 2009   No   No  DISCN
# 45372    78907           4     NaN  Oct 30, 2009   No   No  DISCN
# 45373    78907           5     NaN  Oct 30, 2009   No   No  DISCN
# 45374    78907           6     NaN  Oct 30, 2009   No   No  DISCN
#
#                       applicant_full_name
# 0      PADAGIS ISRAEL PHARMACEUTICALS LTD
# 1               SALIX PHARMACEUTICALS INC
# 2                    JOURNEY MEDICAL CORP
# 3            TEVA PHARMACEUTICALS USA INC
# 4                 NOVAST LABORATORIES LTD
# ...                                   ...
# 45370                          SPECGX LLC
# 45371                          SPECGX LLC
# 45372                          SPECGX LLC
# 45373                          SPECGX LLC
# 45374                          SPECGX LLC
#
# [45375 rows x 14 columns]

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'purple_book'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
purple_book = pd.read_csv(path_csv_file, low_memory=False)
purple_book
# Out:
#         nru                     applicant  bla_number  proprietary_name  \
# 0     N/R/U                     Applicant  BLA Number  Proprietary Name
# 1       NaN  Bristol-Myers Squibb Company      125118           Orencia
# 2       NaN  Bristol-Myers Squibb Company      125118           Orencia
# 3       NaN  Bristol-Myers Squibb Company      125118           Orencia
# 4       NaN  Bristol-Myers Squibb Company      125118           Orencia
# ...     ...                           ...         ...               ...
# 1983    NaN              ModernaTX, Inc.       125796           mresvia
# 1984    NaN                       YIMMUGO      125810           YIMMUGO
# 1985    NaN                       YIMMUGO      125810           YIMMUGO
# 1986    NaN                       YIMMUGO      125810           YIMMUGO
# 1987    NaN       Merck Sharp & Dohme LLC      125814         CAPVAXIVE
#
#                                             proper_name  bla_type    strength  \
# 0                                           Proper Name  BLA Type    Strength
# 1                                             abatacept    351(a)       250MG
# 2                                             abatacept    351(a)    125MG/ML
# 3                                             abatacept    351(a)    125MG/ML
# 4                                             abatacept    351(a)  50MG/0.4ML
# ...                                                 ...       ...         ...
# 1983  Respiratory Syncytial Virus Vaccine, mRNA (mRN...    351(a)   50UG/.5ML
# 1984            immune globulin intravenous, human-dira    351(a)     5G/50ML
# 1985            immune globulin intravenous, human-dira    351(a)   10G/100ML
# 1986            immune globulin intravenous, human-dira    351(a)   20G/200ML
# 1987           Pneumococcal 21-valent Conjugate Vaccine    351(a)   84UG/.5ML
#
#         dosage_form  route_of_administration  product_presentation  ...  \
# 0       Dosage Form  Route of Administration  Product Presentation  ...
# 1     For Injection              Intravenous      Single-Dose Vial  ...
# 2        Injection              Subcutaneous    Pre-Filled Syringe  ...
# 3        Injection              Subcutaneous          Autoinjector  ...
# 4        Injection              Subcutaneous    Pre-Filled Syringe  ...
# ...             ...                      ...                   ...  ...
# 1983  For Injection            Intramuscular    Pre-Filled Syringe  ...
# 1984  For Injection              Intravenous      Single-Dose Vial  ...
# 1985  For Injection              Intravenous      Single-Dose Vial  ...
# 1986  For Injection              Intravenous      Single-Dose Vial  ...
# 1987      Injection            Intramuscular    Pre-Filled Syringe  ...
#
#       supplement_number  submission_type  license_number  product_number  \
# 0     Supplement Number  Submission Type  License Number  Product Number
# 1                   NaN         Original            1713             001
# 2                   122       Supplement            1713             002
# 3                   200       Supplement            1713             003
# 4                   211       Supplement            1713             004
# ...                 ...              ...             ...             ...
# 1983                  0         Original            2256             001
# 1984                  0         Original            2332             001
# 1985                  0         Original            2332             002
# 1986                  0         Original            2332             003
# 1987                  0         Original            0002             001
#
#       center  date_of_first_licensure  exclusivity_expiration_date  \
# 0     Center  Date of First Licensure  Exclusivity Expiration Date
# 1       CDER                      NaN                          NaN
# 2       CDER                      NaN                          NaN
# 3       CDER                      NaN                          NaN
# 4       CDER                      NaN                          NaN
# ...      ...                      ...                          ...
# 1983    CBER                      NaN                          NaN
# 1984    CBER                      NaN                          NaN
# 1985    CBER                      NaN                          NaN
# 1986    CBER                      NaN                          NaN
# 1987    CBER                      NaN                          NaN
#
#        first_interchangeable_exclusivity_exp_date  \
# 0     First Interchangeable Exclusivity Exp. Date
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 1983                                          NaN
# 1984                                          NaN
# 1985                                          NaN
# 1986                                          NaN
# 1987                                          NaN
#
#         ref_product_exclusivity_exp_date   orphan_exclusivity_exp_date
# 0     Ref. Product Exclusivity Exp. Date  Orphan Exclusivity Exp. Date
# 1                                    NaN             December 15, 2028
# 2                                    NaN             December 15, 2028
# 3                                    NaN             December 15, 2028
# 4                                    NaN             December 15, 2028
# ...                                  ...                           ...
# 1983                                 NaN                           NaN
# 1984                                 NaN                           NaN
# 1985                                 NaN                           NaN
# 1986                                 NaN                           NaN
# 1987                                 NaN                           NaN
#
# [1988 rows x 25 columns]

# %% [markdown]
# ## rxclass_atc_to_product

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'rxclass_atc_to_product'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
rxclass_atc_to_product = pd.read_csv(path_csv_file, low_memory=False)
rxclass_atc_to_product
# Out:
#          rxcui class_id                              class_name class_type  \
# 0      1013636    D05AX    Other antipsoriatics for topical use     ATC1-4
# 1      1020035    D05AX    Other antipsoriatics for topical use     ATC1-4
# 2      1020039    D05AX    Other antipsoriatics for topical use     ATC1-4
# 3       108959    D05AX    Other antipsoriatics for topical use     ATC1-4
# 4      1716094    D05AX    Other antipsoriatics for topical use     ATC1-4
# ...        ...      ...                                     ...        ...
# 24321  1299240    C01BG  Other antiarrhythmics, class I and III     ATC1-4
# 24322  1299247    C01BG  Other antiarrhythmics, class I and III     ATC1-4
# 24323  1299251    C01BG  Other antiarrhythmics, class I and III     ATC1-4
# 24324  1490065    G03XC  Selective estrogen receptor modulators     ATC1-4
# 24325  1490067    G03XC  Selective estrogen receptor modulators     ATC1-4
#
#                                                drug_name drug_tty  rela  \
# 0      calcipotriene 0.00005 MG/MG Topical Ointment [...      SBD   NaN
# 1                  calcipotriene 0.05 MG/ML Topical Foam      SCD   NaN
# 2        calcipotriene 0.05 MG/ML Topical Foam [Sorilux]      SBD   NaN
# 3       calcipotriene 0.05 MG/ML Topical Cream [Dovonex]      SBD   NaN
# 4      betamethasone dipropionate 0.643 MG/ML / calci...      SCD   NaN
# ...                                                  ...      ...   ...
# 24321        moricizine hydrochloride 200 MG Oral Tablet      SCD   NaN
# 24322        moricizine hydrochloride 250 MG Oral Tablet      SCD   NaN
# 24323        moricizine hydrochloride 300 MG Oral Tablet      SCD   NaN
# 24324         raloxifene hydrochloride 60 MG Oral Tablet      SCD   NaN
# 24325  raloxifene hydrochloride 60 MG Oral Tablet [Ev...      SBD   NaN
#
#        rela_source
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 24321          NaN
# 24322          NaN
# 24323          NaN
# 24324          NaN
# 24325          NaN
#
# [24326 rows x 8 columns]

# %% [markdown]
# ## rxnorm_historical

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'rxnorm_historical'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
rxnorm_historical = pd.read_csv(path_csv_file, low_memory=False)
rxnorm_historical
# Out:
#                 ndc  start_date  end_date    status  related_rxcui  ndc_list  \
# 0          78007205      200706    200907  indirect         598066       NaN
# 1       55289042920      200706    200907  indirect         598066       NaN
# 2       55289042960      200706    200907  indirect         598066       NaN
# 3       60491062030      200706    200907  indirect         598066       NaN
# 4       60491062034      200706    200907  indirect         598066       NaN
# ...             ...         ...       ...       ...            ...       ...
# 965860  51437010708      202204    202408    direct        1797506       NaN
# 965861  51437010904      202204    202408    direct        1797506       NaN
# 965862  68898011604      202111    202408    direct        1797506       NaN
# 965863  68898011608      202111    202408    direct        1797506       NaN
# 965864  68898011612      202111    202408    direct        1797506       NaN
#
#           rxcui
# 0        857463
# 1        857463
# 2        857463
# 3        857463
# 4        857463
# ...         ...
# 965860  1797506
# 965861  1797506
# 965862  1797506
# 965863  1797506
# 965864  1797506
#
# [965865 rows x 7 columns]

# %% [markdown]
# ## rxnorm_rxnatomarchive

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'rxnorm_rxnatomarchive'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
rxnorm_rxnatomarchive = pd.read_csv(path_csv_file, low_memory=False)
rxnorm_rxnatomarchive
# Out:
#            rxaui        aui  \
# 0            947  A10335796
# 1           1424  A10334758
# 2           1684  A10334529
# 3           2192  A16791816
# 4           2265  A10334531
# ...          ...        ...
# 372152  12888851   12888851
# 372153  12888853   12888853
# 372154  12888857   12888857
# 372155  12899641   12899641
# 372156  12899645   12899645
#
#                                                       str  \
# 0                                                   Mesna
# 1                                            beta-Alanine
# 2                                     4-Aminobenzoic Acid
# 3                                   Eicosapentaenoic Acid
# 4                                     5-Hydroxytryptophan
# ...                                                   ...
# 372152     tovorafenib 3600 MG Powder for Oral Suspension
# 372153                       tovorafenib 3600 MG [Ojemda]
# 372154  tovorafenib 3600 MG Powder for Oral Suspension...
# 372155    Fluzone 2024-2025 vaccine Injectable Suspension
# 372156    Fluzone 2024-2025 vaccine Injectable Suspension
#
#            archive_timestamp     created_timestamp     updated_timestamp  \
# 0       27-APR-2020 00:00:00  10-MAR-2005 00:00:00  27-APR-2020 00:00:00
# 1       27-APR-2020 00:00:00  10-MAR-2005 00:00:00  27-APR-2020 00:00:00
# 2       27-APR-2020 00:00:00  10-MAR-2005 00:00:00  27-APR-2020 00:00:00
# 3       27-APR-2020 00:00:00  10-MAR-2005 00:00:00  27-APR-2020 00:00:00
# 4       27-APR-2020 00:00:00  10-MAR-2005 00:00:00  06-NOV-2020 00:00:00
# ...                      ...                   ...                   ...
# 372152  22-MAY-2024 00:00:00  13-MAY-2024 00:00:00  14-MAY-2024 00:00:00
# 372153  22-MAY-2024 00:00:00  13-MAY-2024 00:00:00  14-MAY-2024 00:00:00
# 372154  22-MAY-2024 00:00:00  13-MAY-2024 00:00:00  14-MAY-2024 00:00:00
# 372155  28-JUL-2024 00:00:00  18-JUL-2024 00:00:00  23-JUL-2024 00:00:00
# 372156  28-JUL-2024 00:00:00  18-JUL-2024 00:00:00  23-JUL-2024 00:00:00
#
#            code  is_brand  lat         last_released  saui  \
# 0            44       NaN  ENG  06-APR-2020 00:00:00   NaN
# 1            61       NaN  ENG  06-APR-2020 00:00:00   NaN
# 2            74       NaN  ENG  06-APR-2020 00:00:00   NaN
# 3            90       NaN  ENG  06-APR-2020 00:00:00   NaN
# 4            94       NaN  ENG  06-APR-2020 00:00:00   NaN
# ...         ...       ...  ...                   ...   ...
# 372152  2682439       NaN  ENG  15-MAY-2024 00:00:00   NaN
# 372153  2682441       NaN  ENG  15-MAY-2024 00:00:00   NaN
# 372154  2682445       NaN  ENG  15-MAY-2024 00:00:00   NaN
# 372155  2688053       NaN  ENG  24-JUL-2024 00:00:00   NaN
# 372156  2688053       NaN  ENG  24-JUL-2024 00:00:00   NaN
#
#                        vsab    rxcui     sab   tty  merged_to_rxcui  blank
# 0       RXNORM_19AB_200406F       44  RXNORM    IN               44    NaN
# 1       RXNORM_19AB_200406F       61  RXNORM    IN               61    NaN
# 2       RXNORM_19AB_200406F       74  RXNORM    IN               74    NaN
# 3       RXNORM_19AB_200406F       90  RXNORM   PIN               90    NaN
# 4       RXNORM_19AB_200406F       94  RXNORM    IN               94    NaN
# ...                     ...      ...     ...   ...              ...    ...
# 372152  RXNORM_20AA_240515W  2682439  RXNORM   SCD          2682439    NaN
# 372153  RXNORM_20AA_240515W  2682441  RXNORM  SBDC          2682441    NaN
# 372154  RXNORM_20AA_240515W  2682445  RXNORM   SBD          2682445    NaN
# 372155  RXNORM_20AA_240724W  2688053  RXNORM    SY          2688053    NaN
# 372156  RXNORM_20AA_240724W  2688053  RXNORM   PSN          2688053    NaN
#
# [372157 rows x 17 columns]

# %% [markdown]
# ## rxnorm_rxnconso

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'rxnorm_rxnconso'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
rxnorm_rxnconso = pd.read_csv(path_csv_file, low_memory=False)
rxnorm_rxnconso
# Out:
#            rxcui  lat  ts  lui  stt  sui  ispref     rxaui        saui  \
# 0              3  ENG NaN  NaN  NaN  NaN     NaN   8717795         NaN
# 1              3  ENG NaN  NaN  NaN  NaN     NaN   8717796         NaN
# 2              3  ENG NaN  NaN  NaN  NaN     NaN   8717808         NaN
# 3              3  ENG NaN  NaN  NaN  NaN     NaN   8718164         NaN
# 4             19  ENG NaN  NaN  NaN  NaN     NaN  10794494         NaN
# ...          ...  ...  ..  ...  ...  ...     ...       ...         ...
# 1150621  2688700  ENG NaN  NaN  NaN  NaN     NaN  12900411  12900411.0
# 1150622  2688700  ENG NaN  NaN  NaN  NaN     NaN  12900412  12900412.0
# 1150623  2688701  ENG NaN  NaN  NaN  NaN     NaN  12900410  12900410.0
# 1150624  2688702  ENG NaN  NaN  NaN  NaN     NaN  12884509         NaN
# 1150625  2688703  ENG NaN  NaN  NaN  NaN     NaN  12892495         NaN
#
#               scui  sdui          sab  tty       code  \
# 0         58488005   NaN  SNOMEDCT_US   PT   58488005
# 1         58488005   NaN  SNOMEDCT_US   FN   58488005
# 2         58488005   NaN  SNOMEDCT_US   SY   58488005
# 3         58488005   NaN  SNOMEDCT_US   SY   58488005
# 4        112116001   NaN  SNOMEDCT_US   SY  112116001
# ...            ...   ...          ...  ...        ...
# 1150621    2688700   NaN       RXNORM   SY    2688700
# 1150622    2688700   NaN       RXNORM  PSN    2688700
# 1150623    2688701   NaN       RXNORM  SBD    2688701
# 1150624        NaN   NaN       MTHSPL   DP  12258-153
# 1150625        NaN   NaN           GS   BD     143007
#
#                                                        str  srl suppress  \
# 0                        1,4-alpha-Glucan branching enzyme  NaN        N
# 1            1,4-alpha-Glucan branching enzyme (substance)  NaN        N
# 2                           Amylo-(1,4,6)-transglycosylase  NaN        N
# 3                                         Branching enzyme  NaN        N
# 4                                   17-hydrocorticosteroid  NaN        N
# ...                                                    ...  ...      ...
# 1150621  Fluzone Quadrivalent 2024-2025 vaccine 0.5 mL ...  NaN        N
# 1150622  Fluzone Quadrivalent 2024-2025 vaccine 0.5 mL ...  NaN        N
# 1150623  influenza A virus A/California/122/2022 (H3N2)...  NaN        E
# 1150624  ISOPROPYL ALCOHOL 950 mg in 1 mL AURICULAR (OT...  NaN        N
# 1150625           Leader Clear Fiber Powder for Suspension  NaN        N
#
#             cvf  blank
# 0           NaN    NaN
# 1           NaN    NaN
# 2           NaN    NaN
# 3           NaN    NaN
# 4           NaN    NaN
# ...         ...    ...
# 1150621  4096.0    NaN
# 1150622  4096.0    NaN
# 1150623     NaN    NaN
# 1150624     NaN    NaN
# 1150625     NaN    NaN
#
# [1150626 rows x 19 columns]

# %% [markdown]
# ## rxnorm_rxncui

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'rxnorm_rxncui'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
rxnorm_rxncui = pd.read_csv(path_csv_file, low_memory=False)
rxnorm_rxncui
# Out:
#           cui1            ver_start              ver_end  cardinality  \
# 0        89904  RXNORM_17AA_170905F  RXNORM_20AA_221003F            1
# 1        91669  RXNORM_17AA_170905F  RXNORM_18AB_181203F            1
# 2        91714  RXNORM_10AA_100802F  RXNORM_10AA_100802F            1
# 3        91811  RXNORM_04AC_050210F  RXNORM_09AA_090706F            1
# 4        91812  RXNORM_04AC_050210F  RXNORM_09AA_090706F            1
# ...        ...                  ...                  ...          ...
# 30212  2639095  RXNORM_20AA_230614W  RXNORM_20AA_230905F            1
# 30213  2639099  RXNORM_20AA_230614W  RXNORM_20AA_230905F            1
# 30214  2639100  RXNORM_20AA_230614W  RXNORM_20AA_230905F            1
# 30215  2639101  RXNORM_20AA_230614W  RXNORM_20AA_230905F            1
# 30216  2641852  RXNORM_20AA_230712W  RXNORM_20AA_230712W            1
#
#           cui2  blank
# 0        89904    NaN
# 1        91669    NaN
# 2      1000992    NaN
# 3       857082    NaN
# 4       857087    NaN
# ...        ...    ...
# 30212  2639095    NaN
# 30213  2639099    NaN
# 30214  2665012    NaN
# 30215  2665017    NaN
# 30216  2642356    NaN
#
# [30217 rows x 6 columns]

# %% [markdown]
# ## rxnorm_rxncuichanges

# %%
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'rxnorm_rxncuichanges'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
# view dataframe
import pandas as pd
rxnorm_rxncuichanges = pd.read_csv(path_csv_file, low_memory=False)
rxnorm_rxncuichanges
# Out:
#         rxaui       code     sab tty  \
# 0     1430112       1701    MMSL  BD
# 1     1453784    4008529   VANDF  CD
# 2     1667297      34598    MMSL  BN
# 3     2372198      12594    MMSL  BD
# 4     2644169       3317      GS  CD
# ..        ...        ...     ...  ..
# 152  12897849     143572      GS  BD
# 153  12897878     143576      GS  BD
# 154  12897886       7505      GS  IN
# 155  12897887       7506      GS  IN
# 156  12900359  82804-131  MTHSPL  DP
#
#                                                    str  old_rxcui  new_rxcui  \
# 0    Hydrocortisone Acetate-Pramoxine HCl, 1%-1% to...    1116499    1235049
# 1                        PSYLLIUM SUGAR FREE PWDR,ORAL     824586    2690884
# 2                                               Alcare     404835    2690059
# 3                    Pneumovax 23, injectable solution    1547585    1547582
# 4           Furosemide 10mg/1mL Solution for injection     899154    1719287
# ..                                                 ...        ...        ...
# 152                               Ovega-3 Mini Softgel    2686775    2689375
# 153        SOFDRA 12.45% Metered Dose Pump Topical Gel    2686659    2689332
# 154                                        Sofpironium    2687073    2689322
# 155                                Sofpironium Bromide    2687074    2689321
# 156                 NITROFURANTOIN 100 mg ORAL CAPSULE    1648755    1648759
#
#      blank
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 152    NaN
# 153    NaN
# 154    NaN
# 155    NaN
# 156    NaN
#
# [157 rows x 8 columns]

# %%
import os
# table_name = str(input("Enter table name: "))

schema = 'sagerx_lake'
table_name = 'rxnorm_rxncuichanges'
csv_file_name = table_name + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
if os.path.isfile(path_csv_file) == True:
    print(f'{table_name} exist')
else:
    host_ip = '192.168.48.129'
    # host_ip = '192.168.48.132'
    import psycopg2
    conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                            port = '5432', user = 'sagerx', password = 'sagerx')
    curs = conn.cursor()
    fid = open(path_csv_file, 'w', encoding="utf-8")
    query = f"SELECT * FROM {schema}.{table_name}"
    sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
    curs.copy_expert(sql, fid)
    fid.close()
# view dataframe
if os.path.isfile(path_csv_file) == True:
    import pandas as pd
    rxnorm_rxncuichanges = pd.read_csv(path_csv_file, low_memory=False)
    rxnorm_rxncuichanges
else:
    print(f'{table_name} not exist')
# Out:
# rxnorm_rxncuichanges exist

# %% [markdown]
# ## rxnorm_rxndoc

# %%
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()

# table_name = str(input("Enter table name: "))
schema = 'sagerx_lake'
table_name = 'rxnorm_rxndoc'
schema_table = schema + '.' + table_name
csv_file_name = table_name.replace('sagerx_lake.', '') + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
fid = open(path_csv_file, 'w', encoding="utf-8")
query = f"SELECT * FROM {schema}.{table_name}"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
import pandas as pd
rxnorm_rxndoc = pd.read_csv(path_csv_file, low_memory=False)
rxnorm_rxndoc

# %% [markdown]
# ## dailymed_daily

# %%
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()

# table_name = str(input("Enter table name: "))
table_name = 'sagerx_lake.dailymed_daily'
csv_file_name = table_name.replace('sagerx_lake.', '') + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
fid = open(path_csv_file, 'w', encoding="utf-8")
query = "SELECT * FROM sagerx_lake.dailymed_daily"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
import pandas as pd
dailymed_daily = pd.read_csv(path_csv_file, low_memory=False)
dailymed_daily
# Out:
#                                                spl  \
# 0    20240824_2ec2afa8-f91a-46cd-ac4e-b8ffa59015ec
# 1    20240824_e1166b3a-a304-4030-ab51-eb55c6e91afd
# 2    20240824_1dbd8448-c1e5-46df-8060-50ef82380445
# 3    20240824_fd4eaf3f-ef9c-4615-9438-a95d91feee06
# 4    20240824_3ba957ea-28ed-4a61-a318-98064ea4944d
# ..                                             ...
# 267  20240907_bc751403-94f2-4f9d-b533-cf6186a40ceb
# 268  20240907_6a104328-3208-4157-be60-8fdc907d3825
# 269  20240907_19816051-c25e-44b5-a127-e846dbd0a8d8
# 270  20240907_3ecff825-34ea-4535-b935-627bf2c13d93
# 271  20240907_ef3b5cbe-f9e1-c1ac-79da-cfe14e3a7e7e
#
#                                     file_name  \
# 0    205ba6f0-3a28-153f-e063-6294a90ab9e2.xml
# 1    e1166b3a-a304-4030-ab51-eb55c6e91afd.xml
# 2    20536f36-1759-8026-e063-6394a90a5103.xml
# 3    205c08c9-a5cd-defb-e063-6294a90a8c3b.xml
# 4    3ac3297d-40ef-488c-bca7-17542d1de0d0.xml
# ..                                        ...
# 267  3f4053b8-3168-4e3b-8257-50bc28c3b58f.xml
# 268  21775d76-4082-e05a-e063-6394a90a2a67.xml
# 269  21587ffd-a2a5-f093-e063-6394a90a6658.xml
# 270  21706a21-fd4b-07a0-e063-6294a90adbbc.xml
# 271  fe4c241c-e545-b24f-818d-53716a837925.xml
#
#                                            xml_content
# 0    <dailymed>\r\n  <documentId>205ba6f0-3a28-153f...
# 1    <dailymed>\r\n  <documentId>e1166b3a-a304-4030...
# 2    <dailymed>\r\n  <documentId>20536f36-1759-8026...
# 3    <dailymed>\r\n  <documentId>205c08c9-a5cd-defb...
# 4    <dailymed>\r\n  <documentId>3ac3297d-40ef-488c...
# ..                                                 ...
# 267  <dailymed>\r\n  <documentId>3f4053b8-3168-4e3b...
# 268  <dailymed>\r\n  <documentId>21775d76-4082-e05a...
# 269  <dailymed>\r\n  <documentId>21587ffd-a2a5-f093...
# 270  <dailymed>\r\n  <documentId>21706a21-fd4b-07a0...
# 271  <dailymed>\r\n  <documentId>fe4c241c-e545-b24f...
#
# [272 rows x 3 columns]

# %% [markdown]
# ## sagerx_lake.orange_book_products

# %%
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()

# table_name = str(input("Enter table name: "))
table_name = 'sagerx_lake.orange_book_products'
csv_file_name = table_name.replace('sagerx_lake.', '') + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
fid = open(path_csv_file, 'w', encoding="utf-8")
query = "SELECT * FROM sagerx_lake.orange_book_products"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
import pandas as pd
orange_book_products = pd.read_csv(path_csv_file, low_memory=False)
orange_book_products
# Out:
#                       ingredient                     df_route  \
# 0                     BUDESONIDE         AEROSOL, FOAM;RECTAL
# 1                     BUDESONIDE         AEROSOL, FOAM;RECTAL
# 2      MINOCYCLINE HYDROCHLORIDE        AEROSOL, FOAM;TOPICAL
# 3                   AZELAIC ACID        AEROSOL, FOAM;TOPICAL
# 4         BETAMETHASONE VALERATE        AEROSOL, FOAM;TOPICAL
# ...                          ...                          ...
# 45370           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 45371           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 45372           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 45373           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
# 45374           FENTANYL CITRATE  TROCHE/LOZENGE;TRANSMUCOSAL
#
#                    trade_name        applicant       strength appl_type  \
# 0                  BUDESONIDE   PADAGIS ISRAEL  2MG/ACTUATION         A
# 1                      UCERIS            SALIX  2MG/ACTUATION         N
# 2                      AMZEEQ          JOURNEY     EQ 4% BASE         N
# 3                AZELAIC ACID  TEVA PHARMS USA            15%         A
# 4      BETAMETHASONE VALERATE      NOVAST LABS          0.12%         A
# ...                       ...              ...            ...       ...
# 45370        FENTANYL CITRATE       SPECGX LLC  EQ 0.4MG BASE         A
# 45371        FENTANYL CITRATE       SPECGX LLC  EQ 0.6MG BASE         A
# 45372        FENTANYL CITRATE       SPECGX LLC  EQ 0.8MG BASE         A
# 45373        FENTANYL CITRATE       SPECGX LLC  EQ 1.2MG BASE         A
# 45374        FENTANYL CITRATE       SPECGX LLC  EQ 1.6MG BASE         A
#
#        appl_no  product_no te_code approval_date  rld   rs   type  \
# 0       215328           1      AB  Apr 12, 2023   No  Yes     RX
# 1       205613           1      AB   Oct 7, 2014  Yes   No     RX
# 2       212379           1     NaN  Oct 18, 2019  Yes  Yes     RX
# 3       210928           1     NaN   Oct 7, 2020   No   No  DISCN
# 4       207144           1     NaN  May 24, 2017   No   No  DISCN
# ...        ...         ...     ...           ...  ...  ...    ...
# 45370    78907           2     NaN  Oct 30, 2009   No   No  DISCN
# 45371    78907           3     NaN  Oct 30, 2009   No   No  DISCN
# 45372    78907           4     NaN  Oct 30, 2009   No   No  DISCN
# 45373    78907           5     NaN  Oct 30, 2009   No   No  DISCN
# 45374    78907           6     NaN  Oct 30, 2009   No   No  DISCN
#
#                       applicant_full_name
# 0      PADAGIS ISRAEL PHARMACEUTICALS LTD
# 1               SALIX PHARMACEUTICALS INC
# 2                    JOURNEY MEDICAL CORP
# 3            TEVA PHARMACEUTICALS USA INC
# 4                 NOVAST LABORATORIES LTD
# ...                                   ...
# 45370                          SPECGX LLC
# 45371                          SPECGX LLC
# 45372                          SPECGX LLC
# 45373                          SPECGX LLC
# 45374                          SPECGX LLC
#
# [45375 rows x 14 columns]

# %% [markdown]
# ## sagerx_lake.rxnorm_rxnrel

# %%
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()

table_name = str(input("Enter table name: "))
csv_file_name = table_name.replace('sagerx_lake.', '') + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
fid = open(path_csv_file, 'w', encoding="utf-8")
query = "SELECT * FROM sagerx_lake.rxnorm_rxnrel"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
import pandas as pd
rxnorm_rxnrel = pd.read_csv(path_csv_file, low_memory=False)
rxnorm_rxnrel
# Out:
# Enter table name:  sagerx_lake.rxnorm_rxnrel
#             rxcui1  rxaui1 stype1 rel     rxcui2     rxaui2 stype2  \
# 0              NaN   828.0    AUI  RO        NaN   788773.0    AUI
# 1              NaN   828.0    AUI  RO        NaN   790716.0    AUI
# 2              NaN   829.0    AUI  SY        NaN      828.0    AUI
# 3              NaN   945.0    AUI  RO        NaN  2369805.0    AUI
# 4              NaN   950.0    AUI  RO        NaN  9251787.0    AUI
# ...            ...     ...    ...  ..        ...        ...    ...
# 7251682  2688701.0     NaN    CUI  RO  2688686.0        NaN    CUI
# 7251683  2688701.0     NaN    CUI  RB  2688687.0        NaN    CUI
# 7251684  2688701.0     NaN    CUI  RB  2688698.0        NaN    CUI
# 7251685  2688701.0     NaN    CUI  RB  2688699.0        NaN    CUI
# 7251686  2688701.0     NaN    CUI  RN  2688700.0        NaN    CUI
#
#                                     rela          rui  srui          sab  sl  \
# 0                         has_ingredient    5066189.0   NaN         MMSL NaN
# 1                         has_ingredient    3823969.0   NaN         MMSL NaN
# 2                                    NaN          NaN   NaN       RXNORM NaN
# 3                         has_ingredient    4306227.0   NaN         MMSL NaN
# 4        has_basis_of_strength_substance  116141227.0   NaN  SNOMEDCT_US NaN
# ...                                  ...          ...   ...          ...  ..
# 7251682                      constitutes  163826750.0   NaN       RXNORM NaN
# 7251683                      inverse_isa  163826760.0   NaN       RXNORM NaN
# 7251684                      inverse_isa  163826748.0   NaN       RXNORM NaN
# 7251685                      inverse_isa  163826762.0   NaN       RXNORM NaN
# 7251686               quantified_form_of  163826767.0   NaN       RXNORM NaN
#
#          dir  rg  suppress  cvf  blank
# 0        NaN NaN       NaN  NaN    NaN
# 1        NaN NaN       NaN  NaN    NaN
# 2        NaN NaN       NaN  NaN    NaN
# 3        NaN NaN       NaN  NaN    NaN
# 4        NaN NaN       NaN  NaN    NaN
# ...      ...  ..       ...  ...    ...
# 7251682  NaN NaN       NaN  NaN    NaN
# 7251683  NaN NaN       NaN  NaN    NaN
# 7251684  NaN NaN       NaN  NaN    NaN
# 7251685  NaN NaN       NaN  NaN    NaN
# 7251686  NaN NaN       NaN  NaN    NaN
#
# [7251687 rows x 17 columns]

# %%
host_ip = '192.168.48.129'
# host_ip = '192.168.48.132'
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host_ip, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()

# %% [markdown]
# ## Extract sagerx_lake.rxterms_ingredients

# %%
fid = open('../sagerxdata/rxterms_ingredients.csv', 'w')

# %%
sql = "COPY (SELECT * FROM sagerx_lake.rxterms_ingredients) TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()

# %%
import pandas as pd
rxterms_ingredients = pd.read_csv('../sagerxdata/rxterms_ingredients.csv')
rxterms_ingredients
# Out:
#          rxcui           ingredient  ing_rxcui
# 0      1000000           olmesartan     321064
# 1      1000000           amlodipine      17767
# 2      1000000  hydrochlorothiazide       5487
# 3      1000001  hydrochlorothiazide       5487
# 4      1000001           olmesartan     321064
# ...        ...                  ...        ...
# 28902   999995           amlodipine      17767
# 28903   999995  hydrochlorothiazide       5487
# 28904   999996  hydrochlorothiazide       5487
# 28905   999996           amlodipine      17767
# 28906   999996           olmesartan     321064
#
# [28907 rows x 3 columns]

# %% [markdown]
# ## sagerx_lake.rxterms

# %%
table_name = str(input("Enter table name: "))
# Out:
# Enter table name:  sagerx_lake.rxterms

# %%
csv_file_name = table_name.replace('sagerx_lake.', '') + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
fid = open(path_csv_file, 'w')
sql = "COPY (SELECT * FROM sagerx_lake.rxterms) TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
import pandas as pd
rxterms = pd.read_csv(path_csv_file)
rxterms
# Out:
#          rxcui  generic_rxcui  tty  \
# 0      1000000       999996.0  SBD
# 1      1000001            NaN  SCD
# 2      1000005      1000001.0  SBD
# 3      1000009            NaN  SCD
# 4      1000048            NaN  SCD
# ...        ...            ...  ...
# 20701   999986            NaN  SCD
# 20702   999990       999986.0  SBD
# 20703   999991            NaN  SCD
# 20704   999995       999991.0  SBD
# 20705   999996            NaN  SCD
#
#                                                full_name  rxn_dose_form  \
# 0      amlodipine 5 MG / hydrochlorothiazide 12.5 MG ...    Oral Tablet
# 1      amlodipine 5 MG / hydrochlorothiazide 25 MG / ...    Oral Tablet
# 2      amlodipine 5 MG / hydrochlorothiazide 25 MG / ...    Oral Tablet
# 3      dimethicone 100 MG/ML / miconazole nitrate 20 ...  Topical Spray
# 4                             doxepin 10 MG Oral Capsule   Oral Capsule
# ...                                                  ...            ...
# 20701  amlodipine 10 MG / hydrochlorothiazide 12.5 MG...    Oral Tablet
# 20702  amlodipine 10 MG / hydrochlorothiazide 12.5 MG...    Oral Tablet
# 20703  amlodipine 10 MG / hydrochlorothiazide 25 MG /...    Oral Tablet
# 20704  amlodipine 10 MG / hydrochlorothiazide 25 MG /...    Oral Tablet
# 20705  amlodipine 5 MG / hydrochlorothiazide 12.5 MG ...    Oral Tablet
#
#                                        full_generic_name brand_name  \
# 0      amlodipine 5 MG / hydrochlorothiazide 12.5 MG ...  TRIBENZOR
# 1      amlodipine 5 MG / hydrochlorothiazide 25 MG / ...        NaN
# 2      amlodipine 5 MG / hydrochlorothiazide 25 MG / ...  TRIBENZOR
# 3      dimethicone 100 MG/ML / miconazole nitrate 20 ...        NaN
# 4                             doxepin 10 MG Oral Capsule        NaN
# ...                                                  ...        ...
# 20701  amlodipine 10 MG / hydrochlorothiazide 12.5 MG...        NaN
# 20702  amlodipine 10 MG / hydrochlorothiazide 12.5 MG...  TRIBENZOR
# 20703  amlodipine 10 MG / hydrochlorothiazide 25 MG /...        NaN
# 20704  amlodipine 10 MG / hydrochlorothiazide 25 MG /...  TRIBENZOR
# 20705  amlodipine 5 MG / hydrochlorothiazide 12.5 MG ...        NaN
#
#                                             display_name      route  \
# 0                                  TRIBENZOR (Oral Pill)  Oral Pill
# 1      amLODIPine/hydroCHLOROthiazide/Olmesartan (Ora...  Oral Pill
# 2                                  TRIBENZOR (Oral Pill)  Oral Pill
# 3            Dimethicone/Miconazole/Zinc oxide (Topical)    Topical
# 4                                    Doxepin (Oral Pill)  Oral Pill
# ...                                                  ...        ...
# 20701  amLODIPine/hydroCHLOROthiazide/Olmesartan (Ora...  Oral Pill
# 20702                              TRIBENZOR (Oral Pill)  Oral Pill
# 20703  amLODIPine/hydroCHLOROthiazide/Olmesartan (Ora...  Oral Pill
# 20704                              TRIBENZOR (Oral Pill)  Oral Pill
# 20705  amLODIPine/hydroCHLOROthiazide/Olmesartan (Ora...  Oral Pill
#
#       new_dose_form       strength suppress_for display_name_synonym  \
# 0               Tab   5-12.5-40 mg          NaN                  NaN
# 1               Tab     5-25-40 mg          NaN                 HCTZ
# 2               Tab     5-25-40 mg          NaN                  NaN
# 3             Spray       10-2-10%          NaN                  ZNO
# 4               Cap          10 mg          NaN                  NaN
# ...             ...            ...          ...                  ...
# 20701           Tab  10-12.5-40 mg          NaN                 HCTZ
# 20702           Tab  10-12.5-40 mg          NaN                  NaN
# 20703           Tab    10-25-40 mg          NaN                 HCTZ
# 20704           Tab    10-25-40 mg          NaN                  NaN
# 20705           Tab   5-12.5-40 mg          NaN                 HCTZ
#
#        is_retired  sxdg_rxcui sxdg_tty  \
# 0             NaN   1182147.0     SBDG
# 1             NaN   1152278.0     SCDG
# 2             NaN   1182147.0     SBDG
# 3             NaN   1159468.0     SCDG
# 4             NaN   1160769.0     SCDG
# ...           ...         ...      ...
# 20701         NaN   1152278.0     SCDG
# 20702         NaN   1182147.0     SBDG
# 20703         NaN   1152278.0     SCDG
# 20704         NaN   1182147.0     SBDG
# 20705         NaN   1152278.0     SCDG
#
#                                                sxdg_name  \
# 0                                         Tribenzor Pill
# 1      amlodipine / hydrochlorothiazide / olmesartan ...
# 2                                         Tribenzor Pill
# 3      dimethicone / miconazole / zinc oxide Topical ...
# 4                                           doxepin Pill
# ...                                                  ...
# 20701  amlodipine / hydrochlorothiazide / olmesartan ...
# 20702                                     Tribenzor Pill
# 20703  amlodipine / hydrochlorothiazide / olmesartan ...
# 20704                                     Tribenzor Pill
# 20705  amlodipine / hydrochlorothiazide / olmesartan ...
#
#                                                      psn
# 0           TRIBENZOR 40 MG / 5 MG / 12.5 MG Oral Tablet
# 1      olmesartan medoxomil 40 MG / amLODIPine 5 MG /...
# 2             TRIBENZOR 40 MG / 5 MG / 25 MG Oral Tablet
# 3      miconazole nitrate 2 % / dimethicone 10 % / zi...
# 4                         doxepin HCl 10 MG Oral Capsule
# ...                                                  ...
# 20701  olmesartan medoxomil 40 MG / amLODIPine 10 MG ...
# 20702      TRIBENZOR 40 MG / 10 MG / 12.5 MG Oral Tablet
# 20703  olmesartan medoxomil 40 MG / amLODIPine 10 MG ...
# 20704        TRIBENZOR 40 MG / 10 MG / 25 MG Oral Tablet
# 20705  olmesartan medoxomil 40 MG / amLODIPine 5 MG /...
#
# [20706 rows x 18 columns]

# %% [markdown]
# ## sagerx_lake.rxnorm_rxnsty

# %%
table_name = str(input("Enter table name: "))
# Out:
# Enter table name:  sagerx_lake.rxnorm_rxnsty

# %%
csv_file_name = table_name.replace('sagerx_lake.', '') + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
fid = open(path_csv_file, 'w')

# %%
sql = "COPY (SELECT * FROM sagerx_lake.rxnorm_rxnsty) TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
import pandas as pd
rxnorm_rxnsty = pd.read_csv(path_csv_file)
rxnorm_rxnsty
# Out:
#           rxcui   tui           stn                              sty  atui  \
# 0             3  T126  A1.4.1.1.3.3                           Enzyme   NaN
# 1             3  T116  A1.4.1.2.1.7  Amino Acid, Peptide, or Protein   NaN
# 2            19  T125  A1.4.1.1.3.2                          Hormone   NaN
# 3            19  T109    A1.4.1.2.1                 Organic Chemical   NaN
# 4            21  T125  A1.4.1.1.3.2                          Hormone   NaN
# ...         ...   ...           ...                              ...   ...
# 470301  2688699  T200        A1.3.3                    Clinical Drug   NaN
# 470302  2688700  T200        A1.3.3                    Clinical Drug   NaN
# 470303  2688701  T200        A1.3.3                    Clinical Drug   NaN
# 470304  2688702  T200        A1.3.3                    Clinical Drug   NaN
# 470305  2688703  T200        A1.3.3                    Clinical Drug   NaN
#
#            cvf  blank
# 0          NaN    NaN
# 1          NaN    NaN
# 2          NaN    NaN
# 3          NaN    NaN
# 4          NaN    NaN
# ...        ...    ...
# 470301  4096.0    NaN
# 470302  4096.0    NaN
# 470303     NaN    NaN
# 470304     NaN    NaN
# 470305     NaN    NaN
#
# [470306 rows x 7 columns]

# %% [markdown]
# ## sagerx_lake.rxnorm_rxnsat

# %%
table_name = str(input("Enter table name: "))
# Out:
# Enter table name:  sagerx_lake.rxnorm_rxnsat

# %%
table_name = str(input("Enter table name: "))
csv_file_name = table_name.replace('sagerx_lake.', '') + '.csv'
path_csv_file = '../sagerxdata/' + csv_file_name
fid = open(path_csv_file, 'w', encoding="utf-8")
query = "SELECT * FROM sagerx_lake.rxnorm_rxnsat"
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()
import pandas as pd
rxnorm_rxnsat = pd.read_csv(path_csv_file, low_memory=False)
rxnorm_rxnsat
# Out:
# Enter table name:  sagerx_lake.rxnorm_rxnsat
#            rxcui  lui  sui     rxaui stype        code atui  satui  \
# 0             38  NaN  NaN       829   AUI          38  NaN    NaN
# 1             44  NaN  NaN       955   AUI      d01411  NaN    NaN
# 2             44  NaN  NaN   2798745   AUI  NR7O1405Q9  NaN    NaN
# 3             44  NaN  NaN   2982613   AUI  NR7O1405Q9  NaN    NaN
# 4             44  NaN  NaN   2982613   AUI  NR7O1405Q9  NaN    NaN
# ...          ...  ...  ...       ...   ...         ...  ...    ...
# 7380164  2691332  NaN  NaN  12905769   AUI      133597  NaN    NaN
# 7380165  2691332  NaN  NaN  12905769   AUI      133597  NaN    NaN
# 7380166  2691332  NaN  NaN  12905769   AUI      133597  NaN    NaN
# 7380167  2691332  NaN  NaN  12905769   AUI      133597  NaN    NaN
# 7380168  2691333  NaN  NaN   8716171  SCUI     DB04918  NaN    NaN
#
#                         atn       sab                                   atv  \
# 0        RXN_BN_CARDINALITY    RXNORM                                single
# 1                       DPC      MMSL                                     N
# 2                SPL_SET_ID    MTHSPL  2a2a526f-636b-7920-4261-6c626f612a2a
# 3                SPL_SET_ID    MTHSPL  1dd56d83-aca3-3e8d-e063-6394a90aa79b
# 4                SPL_SET_ID    MTHSPL  1dd69e84-616d-fb77-e063-6394a90af2f4
# ...                     ...       ...                                   ...
# 7380164                 DST       MMX                           0.5 MG/1 ML
# 7380165             LABELER       MMX                         Patrin Pharma
# 7380166             MMX_RXO       MMX                           OTC/Generic
# 7380167                 NDC       MMX                         39328-0007-50
# 7380168       FDA_UNII_CODE  DRUGBANK                            5T97333YZK
#
#         suppress     cvf  blank
# 0              N  4096.0    NaN
# 1              N     NaN    NaN
# 2              N  4096.0    NaN
# 3              N  4096.0    NaN
# 4              N  4096.0    NaN
# ...          ...     ...    ...
# 7380164        N     NaN    NaN
# 7380165        N     NaN    NaN
# 7380166        N     NaN    NaN
# 7380167        Y     NaN    NaN
# 7380168        N     NaN    NaN
#
# [7380169 rows x 14 columns]

# %%
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = '192.168.48.129', 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()

# export to csv
fid = open('../sagerxdata/dailymed_rxnorm_filtered.csv', 'w')
sql = "COPY (SELECT * FROM sagerx_lake.dailymed_rxnorm WHERE rxstr LIKE '%liquid soap%' OR rxstr LIKE '%Topical Solution%' OR rxstr LIKE '%Facial Scrub%') TO STDOUT WITH CSV HEADER"
curs.copy_expert(sql, fid)
fid.close()

# %% [markdown]
# ### chemas sagerx

# %% [raw]
#                   List of relations
#  Schema |            Name            | Type  | Owner
# --------+----------------------------+-------+--------
#  sagerx | dailymed_interaction       | table | sagerx
#  sagerx | dailymed_organization_text | table | sagerx
#  sagerx | data_availability          | table | sagerx
#  sagerx | pg_stat_statements         | view  | sagerx
#  sagerx | pg_stat_statements_info    | view  | sagerx

# %% [markdown]
# ### chemas sagerxdev

# %%
dailymed_rxnorm_filtered = pd.read_csv('../sagerxdata/dailymed_rxnorm_filtered.csv')
dailymed_rxnorm_filtered.head()
# Out:
#                                   setid  spl_version   rxcui  \
# 0  0001eaa9-e890-4e94-9d44-47a0f3086a02            2  251577
# 1  0001eaa9-e890-4e94-9d44-47a0f3086a02            2  251577
# 2  0001eaa9-e890-4e94-9d44-47a0f3086a02            2  251577
# 3  0001eaa9-e890-4e94-9d44-47a0f3086a02            2  282727
# 4  0001eaa9-e890-4e94-9d44-47a0f3086a02            2  282727
#
#                                       rxstr rxtty
# 0       salicylic acid 2 % Topical Solution   PSN
# 1       salicylic acid 2 % Topical Solution    SY
# 2  salicylic acid 20 MG/ML Topical Solution   SCD
# 3               sulfur 5 % Topical Solution   PSN
# 4               sulfur 5 % Topical Solution    SY

# %%
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()

# %% [markdown]
# ## sagerx_dev.int_mthspl_products_to_inactive_ingredients

# %%
import psycopg2
conn = psycopg2.connect(dbname='sagerx', host = host, 
                        port = '5432', user = 'sagerx', password = 'sagerx')
curs = conn.cursor()


# drug_input = str(input("Enter name: "))
drug_name = str(input("Enter name: "))
# drug_name = drug_input.lower().replace(' ', '+').replace('-','+')

# Save file inactive_ingredient_list.txt
import os
print(drug_name)
drug_name_iig_file = drug_name + "_inactive_ingredient_list.csv"
drug_name_iig_file_path = os.path.join('sagerxdata', drug_name_iig_file)

query = "SELECT * FROM sagerx_dev.int_mthspl_products_to_inactive_ingredients WHERE product_name LIKE '%" + drug_name + "%'" 
fid = open(drug_name_iig_file_path, 'w')
sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"

# print(sql)

curs.copy_expert(sql, fid)
fid.close()


# view data
import os

if os.path.isfile(drug_name_iig_file_path):
    import pandas as pd
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    df_iig = pd.read_csv(drug_name_iig_file_path)
    
    
    import warnings
    warnings.simplefilter(action='ignore', category=FutureWarning)
    from pandasgui import show
    if df_iig is not None:
        drug_name = drug_name.replace('+',' ')
        df_iig_name = {drug_name :df_iig}
        show(**df_iig_name) # show data with pandasgui
else:
    print(f'Inactive ingredient {drug_name} not exist in iigdata!')




# SELECT * FROM sagerx_dev.int_mthspl_products_to_inactive_ingredients WHERE product_name LIKE '%tirzepatide%'


# table_name = str(input("Enter table name: "))
# csv_file = table_name + ".csv"
# query = "SELECT * FROM sagerx_lake." + table_name
# fid = open(csv_file, 'w')
# sql = "COPY (" + query + ") TO STDOUT WITH CSV HEADER"
# print(sql)
