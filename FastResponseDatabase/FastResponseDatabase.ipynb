# %%
ls
# Out:
#  Volume in drive D is RnD0
#  Volume Serial Number is 2417-FA08
#
#  Directory of D:\PharmApp\FastResponseDatabase
#
# 2024-09-23  09:02    <DIR>          .
# 2024-09-23  08:46    <DIR>          ..
# 2024-09-23  08:48    <DIR>          .ipynb_checkpoints
# 2024-09-23  09:02             3.039 FastResponseDatabase.ipynb
# 2024-09-23  08:50    <DIR>          frdb
# 2024-09-23  08:46         3.300.551 frdb-v2023-07-05.zip
# 2024-09-23  08:47                65 Inxight Drugs.url
#                3 File(s)      3.303.655 bytes
#                4 Dir(s)  207.498.248.192 bytes free

# %%
import pandas as pd

# %%
frdb_adverseevents = pd.read_csv('frdb/frdb-adverseevents.tsv', sep='\t')
frdb_adverseevents
# Out:
#           id adverseevents_frequency  adverseevents_frequency_units  \
# 0          1                   5 pts                            NaN
# 1          2                   1 pts                            NaN
# 2          3                   1 pts                            NaN
# 3          4                   5 pts                            NaN
# 4          5                   2 pts                            NaN
# ...      ...                     ...                            ...
# 61268  61269                   1 pts                            NaN
# 61269  61270                      >5                            NaN
# 61270  61271                      >1                            NaN
# 61271  61272                      >5                            NaN
# 61272  61273                     NaN                            NaN
#
#                adverseevents_liability adverseevents_severity  \
# 0                       Abdominal pain          below serious
# ...
